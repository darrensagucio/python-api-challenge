# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "Resources/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 615

# %%
lat_lngs

# %%
cities
# Out:
# ['kokoda',
#  'saint george',
#  'kavieng',
#  'cape town',
#  'lebu',
#  'busselton',
#  'san policarpo',
#  'chuy',
#  'hobart',
#  'gbadolite',
#  'kiruna',
#  'hermanus',
#  'palmer',
#  'acari',
#  'illoqqortoormiut',
#  'punta arenas',
#  'rikitea',
#  'pacific grove',
#  'dunedin',
#  'longyearbyen',
#  'nortelandia',
#  'tanout',
#  'new norfolk',
#  'sola',
#  'avarua',
#  'jiujiang',
#  'artyk',
#  'albany',
#  'steamboat springs',
#  'hami',
#  'severo-kurilsk',
#  'harnai',
#  'ailigandi',
#  'seddon',
#  'hilo',
#  'amderma',
#  'palaiokhora',
#  'macrohon',
#  'sao joao da barra',
#  'emerald',
#  'bluff',
#  'huadian',
#  'narsaq',
#  'halalo',
#  'bredasdorp',
#  'chihuahua',
#  'san patricio',
#  'kapaa',
#  'acapulco',
#  'saint stephen',
#  'san rafael',
#  'dikson',
#  'tsaratanana',
#  'chimbote',
#  'dudinka',
#  'dali',
#  'mataura',
#  'bargal',
#  'castro',
#  'dingle',
#  'puerto ayora',
#  'buriti alegre',
#  'sulangan',
#  'santiago del estero',
#  'cabo san lucas',
#  'victoria',
#  'black river',
#  'saskylakh',
#  'nuuk',
#  'tshikapa',
#  'san cristobal',
#  'bocas del toro',
#  'fortuna',
#  'namatanai',
#  'adrar',
#  'vaitupu',
#  'el monte',
#  'tsihombe',
#  'bengkulu',
#  'umm kaddadah',
#  'avera',
#  'attawapiskat',
#  'betioky',
#  'mibu',
#  'atuona',
#  'bulgan',
#  'chokurdakh',
#  'bridgetown',
#  'coquimbo',
#  'tasiilaq',
#  'kashi',
#  'ponta do sol',
#  'puerto quijarro',
#  'petropavlovsk-kamchatskiy',
#  'khatanga',
#  'airai',
#  'upernavik',
#  'fereydun kenar',
#  'jamestown',
#  'russell',
#  'provideniya',
#  'leningradskiy',
#  'la ciotat',
#  'iqaluit',
#  'bethel',
#  'east london',
#  'faya',
#  'bambous virieux',
#  'gat',
#  'mahajanga',
#  'ulladulla',
#  'hithadhoo',
#  'lavrentiya',
#  'portland',
#  'nome',
#  'cidreira',
#  'torbay',
#  'yarim',
#  'qaanaaq',
#  'talara',
#  'sinnamary',
#  'namibe',
#  'taolanaro',
#  'kidal',
#  'saleaula',
#  'prince rupert',
#  'aragarcas',
#  'kruisfontein',
#  'tuktoyaktuk',
#  'cherskiy',
#  'mys shmidta',
#  'codrington',
#  'serenje',
#  'vaini',
#  'port lincoln',
#  'barentsburg',
#  'hualmay',
#  'tasbuget',
#  'butaritari',
#  'tautira',
#  'kodiak',
#  'kolosovka',
#  'maharajganj',
#  'hendijan',
#  'arraial do cabo',
#  'aras',
#  'jinchengjiang',
#  'tilichiki',
#  'port alfred',
#  'ushuaia',
#  'haverfordwest',
#  'kahului',
#  'bokoro',
#  'hay river',
#  'norman wells',
#  'kudahuvadhoo',
#  'pauna',
#  'yar-sale',
#  'la maddalena',
#  'fare',
#  'georgetown',
#  'tarudant',
#  'hofn',
#  'praia',
#  'shingu',
#  'povorino',
#  'klaksvik',
#  'mealhada',
#  'vangaindrano',
#  'ye',
#  'sentyabrskiy',
#  'dourbali',
#  'geraldton',
#  'siswa bazar',
#  'husavik',
#  'barrow',
#  'katsuura',
#  'berlevag',
#  'port elizabeth',
#  'belushya guba',
#  'zhigansk',
#  'nizhneyansk',
#  'mar del plata',
#  'cayenne',
#  'yellowknife',
#  'mazatlan',
#  'fasa',
#  'seoul',
#  'komsomolskiy',
#  'lorengau',
#  'bay roberts',
#  'asau',
#  'honningsvag',
#  'grand river south east',
#  'ilulissat',
#  'bur gabo',
#  'maridi',
#  'te anau',
#  'laukaa',
#  'hobyo',
#  'puri',
#  'srednekolymsk',
#  'bilma',
#  'marcona',
#  'tarakan',
#  'saint-philippe',
#  'springdale',
#  'saldanha',
#  'sterling',
#  'puerto escondido',
#  'creetown',
#  'port hardy',
#  'karaul',
#  'ancud',
#  'nizwa',
#  'atar',
#  'simao',
#  'trinidad',
#  'mgandu',
#  'marsh harbour',
#  'guerrero negro',
#  'walvis bay',
#  'kulhudhuffushi',
#  'nioro',
#  'nikolskoye',
#  'richards bay',
#  'carbonia',
#  'flinders',
#  'san ignacio',
#  'cantagallo',
#  'dzhebariki-khaya',
#  'mount isa',
#  'sakaiminato',
#  'chebenki',
#  'henties bay',
#  'ternate',
#  'beringovskiy',
#  'college',
#  'tumannyy',
#  'thompson',
#  'ferrol',
#  'santa isabel do rio negro',
#  'aginskoye',
#  'manzil tamim',
#  'kazachinskoye',
#  'meulaboh',
#  'baherden',
#  'jocoro',
#  'carlsbad',
#  'burns lake',
#  'arcata',
#  'tela',
#  'ostrovnoy',
#  'fundong',
#  'bonthe',
#  'homer',
#  'pontes e lacerda',
#  'paysandu',
#  'ribeira grande',
#  'ballina',
#  'tura',
#  'saint-francois',
#  'namie',
#  'broken hill',
#  'tupik',
#  'stokmarknes',
#  'spas-demensk',
#  'sitka',
#  'katobu',
#  'kikwit',
#  'svetlogorsk',
#  'alofi',
#  'matadi',
#  'santa maria',
#  'maloshuyka',
#  'grenaa',
#  'zhigalovo',
#  'pevek',
#  'eyl',
#  'pathein',
#  'umzimvubu',
#  'los llanos de aridane',
#  'saint anthony',
#  'balingasay',
#  'kunnamangalam',
#  'vadinsk',
#  'hambantota',
#  'severodvinsk',
#  'carnarvon',
#  'mersing',
#  'vestmanna',
#  'tupancireta',
#  'ngunguru',
#  'puntarenas',
#  'axim',
#  'maxixe',
#  'turukhansk',
#  'conceicao do mato dentro',
#  'appiano',
#  'zambezi',
#  'hasaki',
#  'stephenville',
#  'bonavista',
#  'tahta',
#  'utiroa',
#  'barahona',
#  'cockburn town',
#  'kaitangata',
#  'manado',
#  'winnemucca',
#  'viedma',
#  'half moon bay',
#  'esperance',
#  'lokosovo',
#  'colesberg',
#  'coihaique',
#  'nguiu',
#  'fairbanks',
#  'kamenskoye',
#  'naze',
#  'toliary',
#  'emporia',
#  'rosia',
#  'lagoa',
#  'bosaso',
#  'tezu',
#  'synya',
#  'ushtobe',
#  'bani',
#  'severnoye',
#  'nagato',
#  'pringsewu',
#  'ongandjera',
#  'dalbandin',
#  'calabozo',
#  'san luis',
#  'nzerekore',
#  'touros',
#  'kibaya',
#  'mana',
#  'nieuw amsterdam',
#  'beyneu',
#  'sumbawa',
#  'mahinog',
#  'nantucket',
#  'namtsy',
#  'biu',
#  'mongu',
#  'nanortalik',
#  'alyangula',
#  'mwinilunga',
#  'sao francisco de paula',
#  'graaff-reinet',
#  'luwuk',
#  'denpasar',
#  'egvekinot',
#  'noumea',
#  'samarai',
#  'yumen',
#  'alamor',
#  'road town',
#  'praia da vitoria',
#  'loandjili',
#  'port macquarie',
#  'jaipur hat',
#  'miles city',
#  'ust-charyshskaya pristan',
#  'gambiran',
#  'lodwar',
#  'nassau',
#  'nyurba',
#  'melo',
#  'vilyuysk',
#  'lakes entrance',
#  'rungata',
#  'najran',
#  'goderich',
#  'baytown',
#  'kasongo-lunda',
#  'pahrump',
#  'santa eulalia del rio',
#  'salekhard',
#  'kununurra',
#  'whitehorse',
#  'caravelas',
#  'zavodoukovsk',
#  'troitsk',
#  'aksarka',
#  'marsa matruh',
#  'kuminskiy',
#  'pisco',
#  'margate',
#  'churapcha',
#  'qaqortoq',
#  'ratnagiri',
#  'chapais',
#  'teeli',
#  'sistranda',
#  'mamallapuram',
#  'tazovskiy',
#  'pangody',
#  'fort saint john',
#  'sao raimundo das mangabeiras',
#  'barpathar',
#  'gataia',
#  'manta',
#  'malatya',
#  'grindavik',
#  'abu kamal',
#  'constitucion',
#  'soyo',
#  'hameenlinna',
#  'pangnirtung',
#  'sao filipe',
#  'aflu',
#  'baoqing',
#  'makakilo city',
#  'christchurch',
#  'shache',
#  'schalksmuhle',
#  'dubbo',
#  'vao',
#  'kotaparh',
#  'lompoc',
#  'mugur-aksy',
#  'magdagachi',
#  'naryan-mar',
#  'camocim',
#  'todos santos',
#  'luderitz',
#  'mudu',
#  'nchelenge',
#  'barreirinhas',
#  'mendi',
#  'vila velha',
#  'tolosa',
#  'hornepayne',
#  'kutiyana',
#  'george town',
#  'blatna',
#  'le port',
#  'puga',
#  'ossora',
#  'baft',
#  'clovis',
#  'tuatapere',
#  'bathsheba',
#  'ticusul',
#  'zhanaozen',
#  'vinh',
#  'marabba',
#  'mount gambier',
#  'altoona',
#  'ixtapa',
#  'nigran',
#  'pedernales',
#  'souillac',
#  'waddan',
#  'torrington',
#  'kushima',
#  'faanui',
#  'srandakan',
#  'kotelnich',
#  'benghazi',
#  'itarema',
#  'sao miguel do araguaia',
#  'bloomfield',
#  'banda aceh',
#  'coari',
#  'usinsk',
#  'saint-joseph',
#  'solsvik',
#  'moerai',
#  'kracheh',
#  'nizhnyaya pavlovka',
#  'maragogi',
#  'scarborough',
#  'belyy yar',
#  'xiaoshi',
#  'mlowo',
#  'maceio',
#  'garowe',
#  'aksu',
#  'olafsvik',
#  'bangkalan',
#  'tingi',
#  'mulchen',
#  'louisbourg',
#  'lufkin',
#  'ginir',
#  'mahebourg',
#  'oistins',
#  'skelleftea',
#  'sambava',
#  'dryden',
#  'aldan',
#  'great bend',
#  'pokhara',
#  'palana',
#  'kirakira',
#  'portmore',
#  'itaituba',
#  'beloha',
#  'nelson bay',
#  'mardin',
#  'narang',
#  'matara',
#  'muscatine',
#  'praya',
#  'murwara',
#  'athabasca',
#  'galle',
#  'lisala',
#  'high level',
#  'rocky mountain house',
#  'timizart',
#  'tsumeb',
#  'tiksi',
#  'vostok',
#  'la ronge',
#  'ugoofaaru',
#  'daoukro',
#  'paraiso',
#  'bawku',
#  'micheweni',
#  'xichang',
#  'starokostyantyniv',
#  'yerbogachen',
#  'santa fe',
#  'kamaishi',
#  'stodolishche',
#  'plettenberg bay',
#  'khash',
#  'payson',
#  'grand-santi',
#  'cravo norte',
#  'pemangkat',
#  'eureka',
#  'warrnambool',
#  'miyang',
#  'awbari',
#  'malwan',
#  'malindi',
#  'ilhabela',
#  'vardo',
#  'qeshm',
#  'eydhafushi',
#  'haines junction',
#  'santa rosa',
#  'sur',
#  'waverley',
#  'whitianga',
#  'oussouye',
#  'viligili',
#  'riaba',
#  'grand gaube',
#  'shumskiy',
#  'nebolchi',
#  'xiaoshan',
#  'zhangye',
#  'lasa',
#  'auki',
#  'khonuu',
#  'tokur',
#  'makat',
#  'petauke',
#  'opuwo',
#  'wahran',
#  'hirara',
#  'luanda',
#  'bajo baudo',
#  'krasnogorskoye',
#  'balkanabat',
#  'rio gallegos',
#  'trabzon',
#  'bac lieu',
#  'suluq',
#  'isla mujeres',
#  'comodoro rivadavia',
#  'rassvet',
#  'muros',
#  'urucara',
#  'hamilton',
#  'maragheh',
#  'banjar',
#  'falealupo',
#  'cheuskiny',
#  'bandipur',
#  'kenai',
#  'rapid valley',
#  'mwense',
#  'vila franca do campo',
#  'mackay',
#  'ola',
#  'trairi',
#  'devonport',
#  'macroom',
#  'lannion',
#  'irati',
#  'north bend',
#  'takoradi',
#  'kaluderica',
#  'sandwick',
#  'valparaiso',
#  'passo de camaragibe',
#  'yeniseysk',
#  'birjand',
#  'puerto madero',
#  'afikpo',
#  'buchanan',
#  'flin flon',
#  'karratha',
#  'general roca',
#  'varkaus',
#  'police']

# %%
city = cities[0]
city
# Out:
# 'kokoda'

# %%
url = f"http://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}"

# %%
weather_response = requests.get(url)
city_weather_json = weather_response.json()
city_weather_json
# Out:
# {'coord': {'lon': 147.7407, 'lat': -8.8785},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 295.82,
#   'feels_like': 298.93,
#   'temp_min': 295.82,
#   'temp_max': 295.82,
#   'pressure': 1008,
#   'humidity': 86,
#   'sea_level': 1008,
#   'grnd_level': 968},
#  'visibility': 10000,
#  'wind': {'speed': 0.97, 'deg': 223, 'gust': 1.68},
#  'clouds': {'all': 100},
#  'dt': 1616097696,
#  'sys': {'country': 'PG', 'sunrise': 1616098389, 'sunset': 1616142040},
#  'timezone': 36000,
#  'id': 2093691,
#  'name': 'Kokoda',
#  'cod': 200}

# %%
max_temp = city_weather_json['main']['temp_max']
max_temp
# Out:
# 295.82

# %%
city_weather_json['coord']
# Out:
# {'lon': 147.7407, 'lat': -8.8785}

# %%
city_weather_json['clouds']['all']
# Out:
# 100

# %%
forecast = city_weather_json["weather"][0]["main"]
forecast
# Out:
# 'Clouds'

# %%
latcheck = city_weather_json["coord"]["lat"]
latcheck
# Out:
# -8.8785

# %%
cities_df = pd.DataFrame({"City":cities,})
cities_df
# Out:
#              City
# 0          kokoda
# 1    saint george
# 2         kavieng
# 3       cape town
# 4            lebu
# ..            ...
# 610     flin flon
# 611      karratha
# 612  general roca
# 613       varkaus
# 614        police
#
# [615 rows x 1 columns]

# %%
cities_df['Lat']= ""
cities_df['Lng']= ""
cities_df['Max Temp']= ""
cities_df['Humidity']= ""
cities_df['Cloudiness']= ""
cities_df['Wind Speed']= ""
cities_df['Country']= ""
cities_df['Date']= ""
cities_df
# Out:
#              City Lat Lng Max Temp Humidity Cloudiness Wind Speed Country Date
# 0          kokoda
# 1    saint george
# 2         kavieng
# 3       cape town
# 4            lebu
# ..            ...  ..  ..      ...      ...        ...        ...     ...  ...
# 610     flin flon
# 611      karratha
# 612  general roca
# 613       varkaus
# 614        police
#
# [615 rows x 9 columns]

# %%
base_url = "http://api.openweathermap.org/data/2.5/weather"
city_name = cities[0] # where cities[0] is katsuura
params = {"q":city_name,
          "appid":weather_api_key}
get_city_response = requests.get(base_url, params=params).json()
get_city_response
# Out:
# {'coord': {'lon': 147.7407, 'lat': -8.8785},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 295.82,
#   'feels_like': 298.93,
#   'temp_min': 295.82,
#   'temp_max': 295.82,
#   'pressure': 1008,
#   'humidity': 86,
#   'sea_level': 1008,
#   'grnd_level': 968},
#  'visibility': 10000,
#  'wind': {'speed': 0.97, 'deg': 223, 'gust': 1.68},
#  'clouds': {'all': 100},
#  'dt': 1616097696,
#  'sys': {'country': 'PG', 'sunrise': 1616098389, 'sunset': 1616142040},
#  'timezone': 36000,
#  'id': 2093691,
#  'name': 'Kokoda',
#  'cod': 200}

# %%
base_url = "http://api.openweathermap.org/data/2.5/weather"
city_name = cities[1] 
params = {"q":city_name,
          "appid":weather_api_key}
get_city_response = requests.get(base_url, params=params).json()
get_city_response
# Out:
# {'coord': {'lon': -113.5841, 'lat': 37.1041},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01d'}],
#  'base': 'stations',
#  'main': {'temp': 291.39,
#   'feels_like': 288.83,
#   'temp_min': 288.15,
#   'temp_max': 292.59,
#   'pressure': 1021,
#   'humidity': 47},
#  'visibility': 10000,
#  'wind': {'speed': 2.57, 'deg': 230},
#  'clouds': {'all': 1},
#  'dt': 1616097697,
#  'sys': {'type': 1,
#   'id': 5832,
#   'country': 'US',
#   'sunrise': 1616074823,
#   'sunset': 1616118252},
#  'timezone': -21600,
#  'id': 5546220,
#  'name': 'Saint George',
#  'cod': 200}

# %%
base_url = "http://api.openweathermap.org/data/2.5/weather?"
params = {"appid":weather_api_key}

set_number = 0
record_number = 0 

print("Beginning Data Retrieval")
print("--------------------------------")

# For Loop To Extract Data From API 
for index, row in cities_df.iterrows():
    
    #
    choosing_city = row['City']
    
    #  
    params['q'] = choosing_city
    
    #
    get_city_response = requests.get(base_url, params=params).json()
    
    try:
        cities_df.loc[index, 'Lat'] = get_city_response["coord"]["lat"]
        cities_df.loc[index, 'Lng'] = get_city_response["coord"]["lon"]
        cities_df.loc[index, 'Max Temp'] = get_city_response["main"]["temp_max"]
        cities_df.loc[index, 'Humidity'] = get_city_response["main"]["humidity"]
        cities_df.loc[index, 'Cloudiness'] = get_city_response["clouds"]["all"]
        cities_df.loc[index, 'Wind Speed'] = get_city_response["wind"]["speed"]
        cities_df.loc[index, 'Country'] = get_city_response["sys"]["country"]
        cities_df.loc[index, 'Date'] = get_city_response["dt"]
        record_number += 1 
        if record_number == 50:
            record_number = 0 
            set_number += 1
        print(f"Processing Record {record_number} of Set {set_number} | {choosing_city}") 
    
    except (KeyError):
        print("City not found. Skipping...")

print("--------------------------------")
print("Data Retrieval Complete")
print("--------------------------------")
# Out:
# Beginning Data Retrieval
# --------------------------------
# Processing Record 1 of Set 0 | kokoda
# Processing Record 2 of Set 0 | saint george
# Processing Record 3 of Set 0 | kavieng
# Processing Record 4 of Set 0 | cape town
# Processing Record 5 of Set 0 | lebu
# Processing Record 6 of Set 0 | busselton
# Processing Record 7 of Set 0 | san policarpo
# Processing Record 8 of Set 0 | chuy
# Processing Record 9 of Set 0 | hobart
# Processing Record 10 of Set 0 | gbadolite
# Processing Record 11 of Set 0 | kiruna
# Processing Record 12 of Set 0 | hermanus
# Processing Record 13 of Set 0 | palmer
# Processing Record 14 of Set 0 | acari
# City not found. Skipping...
# Processing Record 15 of Set 0 | punta arenas
# Processing Record 16 of Set 0 | rikitea
# Processing Record 17 of Set 0 | pacific grove
# Processing Record 18 of Set 0 | dunedin
# Processing Record 19 of Set 0 | longyearbyen
# Processing Record 20 of Set 0 | nortelandia
# Processing Record 21 of Set 0 | tanout
# Processing Record 22 of Set 0 | new norfolk
# Processing Record 23 of Set 0 | sola
# Processing Record 24 of Set 0 | avarua
# Processing Record 25 of Set 0 | jiujiang
# City not found. Skipping...
# Processing Record 26 of Set 0 | albany
# Processing Record 27 of Set 0 | steamboat springs
# Processing Record 28 of Set 0 | hami
# Processing Record 29 of Set 0 | severo-kurilsk
# Processing Record 30 of Set 0 | harnai
# Processing Record 31 of Set 0 | ailigandi
# Processing Record 32 of Set 0 | seddon
# Processing Record 33 of Set 0 | hilo
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 34 of Set 0 | macrohon
# Processing Record 35 of Set 0 | sao joao da barra
# Processing Record 36 of Set 0 | emerald
# Processing Record 37 of Set 0 | bluff
# Processing Record 38 of Set 0 | huadian
# Processing Record 39 of Set 0 | narsaq
# City not found. Skipping...
# Processing Record 40 of Set 0 | bredasdorp
# Processing Record 41 of Set 0 | chihuahua
# Processing Record 42 of Set 0 | san patricio
# Processing Record 43 of Set 0 | kapaa
# Processing Record 44 of Set 0 | acapulco
# Processing Record 45 of Set 0 | saint stephen
# Processing Record 46 of Set 0 | san rafael
# Processing Record 47 of Set 0 | dikson
# Processing Record 48 of Set 0 | tsaratanana
# Processing Record 49 of Set 0 | chimbote
# Processing Record 0 of Set 1 | dudinka
# Processing Record 1 of Set 1 | dali
# Processing Record 2 of Set 1 | mataura
# City not found. Skipping...
# Processing Record 3 of Set 1 | castro
# Processing Record 4 of Set 1 | dingle
# Processing Record 5 of Set 1 | puerto ayora
# Processing Record 6 of Set 1 | buriti alegre
# Processing Record 7 of Set 1 | sulangan
# Processing Record 8 of Set 1 | santiago del estero
# Processing Record 9 of Set 1 | cabo san lucas
# Processing Record 10 of Set 1 | victoria
# Processing Record 11 of Set 1 | black river
# Processing Record 12 of Set 1 | saskylakh
# Processing Record 13 of Set 1 | nuuk
# Processing Record 14 of Set 1 | tshikapa
# Processing Record 15 of Set 1 | san cristobal
# Processing Record 16 of Set 1 | bocas del toro
# Processing Record 17 of Set 1 | fortuna
# Processing Record 18 of Set 1 | namatanai
# Processing Record 19 of Set 1 | adrar
# City not found. Skipping...
# Processing Record 20 of Set 1 | el monte
# City not found. Skipping...
# Processing Record 21 of Set 1 | bengkulu
# Processing Record 22 of Set 1 | umm kaddadah
# Processing Record 23 of Set 1 | avera
# City not found. Skipping...
# Processing Record 24 of Set 1 | betioky
# Processing Record 25 of Set 1 | mibu
# Processing Record 26 of Set 1 | atuona
# Processing Record 27 of Set 1 | bulgan
# Processing Record 28 of Set 1 | chokurdakh
# Processing Record 29 of Set 1 | bridgetown
# Processing Record 30 of Set 1 | coquimbo
# Processing Record 31 of Set 1 | tasiilaq
# Processing Record 32 of Set 1 | kashi
# Processing Record 33 of Set 1 | ponta do sol
# Processing Record 34 of Set 1 | puerto quijarro
# Processing Record 35 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 36 of Set 1 | khatanga
# Processing Record 37 of Set 1 | airai
# Processing Record 38 of Set 1 | upernavik
# Processing Record 39 of Set 1 | fereydun kenar
# Processing Record 40 of Set 1 | jamestown
# Processing Record 41 of Set 1 | russell
# Processing Record 42 of Set 1 | provideniya
# Processing Record 43 of Set 1 | leningradskiy
# Processing Record 44 of Set 1 | la ciotat
# Processing Record 45 of Set 1 | iqaluit
# Processing Record 46 of Set 1 | bethel
# Processing Record 47 of Set 1 | east london
# Processing Record 48 of Set 1 | faya
# Processing Record 49 of Set 1 | bambous virieux
# Processing Record 0 of Set 2 | gat
# Processing Record 1 of Set 2 | mahajanga
# Processing Record 2 of Set 2 | ulladulla
# Processing Record 3 of Set 2 | hithadhoo
# Processing Record 4 of Set 2 | lavrentiya
# Processing Record 5 of Set 2 | portland
# Processing Record 6 of Set 2 | nome
# Processing Record 7 of Set 2 | cidreira
# Processing Record 8 of Set 2 | torbay
# Processing Record 9 of Set 2 | yarim
# Processing Record 10 of Set 2 | qaanaaq
# Processing Record 11 of Set 2 | talara
# Processing Record 12 of Set 2 | sinnamary
# Processing Record 13 of Set 2 | namibe
# City not found. Skipping...
# Processing Record 14 of Set 2 | kidal
# City not found. Skipping...
# Processing Record 15 of Set 2 | prince rupert
# Processing Record 16 of Set 2 | aragarcas
# Processing Record 17 of Set 2 | kruisfontein
# Processing Record 18 of Set 2 | tuktoyaktuk
# Processing Record 19 of Set 2 | cherskiy
# City not found. Skipping...
# Processing Record 20 of Set 2 | codrington
# Processing Record 21 of Set 2 | serenje
# Processing Record 22 of Set 2 | vaini
# Processing Record 23 of Set 2 | port lincoln
# City not found. Skipping...
# Processing Record 24 of Set 2 | hualmay
# City not found. Skipping...
# Processing Record 25 of Set 2 | butaritari
# Processing Record 26 of Set 2 | tautira
# Processing Record 27 of Set 2 | kodiak
# Processing Record 28 of Set 2 | kolosovka
# Processing Record 29 of Set 2 | maharajganj
# City not found. Skipping...
# Processing Record 30 of Set 2 | arraial do cabo
# Processing Record 31 of Set 2 | aras
# City not found. Skipping...
# Processing Record 32 of Set 2 | tilichiki
# Processing Record 33 of Set 2 | port alfred
# Processing Record 34 of Set 2 | ushuaia
# Processing Record 35 of Set 2 | haverfordwest
# Processing Record 36 of Set 2 | kahului
# Processing Record 37 of Set 2 | bokoro
# Processing Record 38 of Set 2 | hay river
# Processing Record 39 of Set 2 | norman wells
# Processing Record 40 of Set 2 | kudahuvadhoo
# Processing Record 41 of Set 2 | pauna
# Processing Record 42 of Set 2 | yar-sale
# Processing Record 43 of Set 2 | la maddalena
# Processing Record 44 of Set 2 | fare
# Processing Record 45 of Set 2 | georgetown
# City not found. Skipping...
# Processing Record 46 of Set 2 | hofn
# Processing Record 47 of Set 2 | praia
# Processing Record 48 of Set 2 | shingu
# Processing Record 49 of Set 2 | povorino
# Processing Record 0 of Set 3 | klaksvik
# Processing Record 1 of Set 3 | mealhada
# Processing Record 2 of Set 3 | vangaindrano
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 3 of Set 3 | dourbali
# Processing Record 4 of Set 3 | geraldton
# Processing Record 5 of Set 3 | siswa bazar
# Processing Record 6 of Set 3 | husavik
# Processing Record 7 of Set 3 | barrow
# Processing Record 8 of Set 3 | katsuura
# Processing Record 9 of Set 3 | berlevag
# Processing Record 10 of Set 3 | port elizabeth
# City not found. Skipping...
# Processing Record 11 of Set 3 | zhigansk
# City not found. Skipping...
# Processing Record 12 of Set 3 | mar del plata
# Processing Record 13 of Set 3 | cayenne
# Processing Record 14 of Set 3 | yellowknife
# Processing Record 15 of Set 3 | mazatlan
# Processing Record 16 of Set 3 | fasa
# Processing Record 17 of Set 3 | seoul
# Processing Record 18 of Set 3 | komsomolskiy
# Processing Record 19 of Set 3 | lorengau
# Processing Record 20 of Set 3 | bay roberts
# Processing Record 21 of Set 3 | asau
# Processing Record 22 of Set 3 | honningsvag
# City not found. Skipping...
# Processing Record 23 of Set 3 | ilulissat
# City not found. Skipping...
# Processing Record 24 of Set 3 | maridi
# Processing Record 25 of Set 3 | te anau
# Processing Record 26 of Set 3 | laukaa
# Processing Record 27 of Set 3 | hobyo
# Processing Record 28 of Set 3 | puri
# Processing Record 29 of Set 3 | srednekolymsk
# Processing Record 30 of Set 3 | bilma
# City not found. Skipping...
# Processing Record 31 of Set 3 | tarakan
# Processing Record 32 of Set 3 | saint-philippe
# Processing Record 33 of Set 3 | springdale
# Processing Record 34 of Set 3 | saldanha
# Processing Record 35 of Set 3 | sterling
# Processing Record 36 of Set 3 | puerto escondido
# Processing Record 37 of Set 3 | creetown
# Processing Record 38 of Set 3 | port hardy
# City not found. Skipping...
# Processing Record 39 of Set 3 | ancud
# Processing Record 40 of Set 3 | nizwa
# Processing Record 41 of Set 3 | atar
# Processing Record 42 of Set 3 | simao
# Processing Record 43 of Set 3 | trinidad
# Processing Record 44 of Set 3 | mgandu
# Processing Record 45 of Set 3 | marsh harbour
# Processing Record 46 of Set 3 | guerrero negro
# Processing Record 47 of Set 3 | walvis bay
# Processing Record 48 of Set 3 | kulhudhuffushi
# Processing Record 49 of Set 3 | nioro
# Processing Record 0 of Set 4 | nikolskoye
# Processing Record 1 of Set 4 | richards bay
# Processing Record 2 of Set 4 | carbonia
# Processing Record 3 of Set 4 | flinders
# Processing Record 4 of Set 4 | san ignacio
# Processing Record 5 of Set 4 | cantagallo
# Processing Record 6 of Set 4 | dzhebariki-khaya
# Processing Record 7 of Set 4 | mount isa
# Processing Record 8 of Set 4 | sakaiminato
# Processing Record 9 of Set 4 | chebenki
# Processing Record 10 of Set 4 | henties bay
# Processing Record 11 of Set 4 | ternate
# Processing Record 12 of Set 4 | beringovskiy
# Processing Record 13 of Set 4 | college
# City not found. Skipping...
# Processing Record 14 of Set 4 | thompson
# Processing Record 15 of Set 4 | ferrol
# Processing Record 16 of Set 4 | santa isabel do rio negro
# Processing Record 17 of Set 4 | aginskoye
# City not found. Skipping...
# Processing Record 18 of Set 4 | kazachinskoye
# Processing Record 19 of Set 4 | meulaboh
# Processing Record 20 of Set 4 | baherden
# Processing Record 21 of Set 4 | jocoro
# Processing Record 22 of Set 4 | carlsbad
# Processing Record 23 of Set 4 | burns lake
# Processing Record 24 of Set 4 | arcata
# Processing Record 25 of Set 4 | tela
# Processing Record 26 of Set 4 | ostrovnoy
# Processing Record 27 of Set 4 | fundong
# Processing Record 28 of Set 4 | bonthe
# Processing Record 29 of Set 4 | homer
# Processing Record 30 of Set 4 | pontes e lacerda
# Processing Record 31 of Set 4 | paysandu
# Processing Record 32 of Set 4 | ribeira grande
# Processing Record 33 of Set 4 | ballina
# Processing Record 34 of Set 4 | tura
# Processing Record 35 of Set 4 | saint-francois
# Processing Record 36 of Set 4 | namie
# Processing Record 37 of Set 4 | broken hill
# Processing Record 38 of Set 4 | tupik
# Processing Record 39 of Set 4 | stokmarknes
# Processing Record 40 of Set 4 | spas-demensk
# Processing Record 41 of Set 4 | sitka
# Processing Record 42 of Set 4 | katobu
# Processing Record 43 of Set 4 | kikwit
# Processing Record 44 of Set 4 | svetlogorsk
# Processing Record 45 of Set 4 | alofi
# Processing Record 46 of Set 4 | matadi
# Processing Record 47 of Set 4 | santa maria
# City not found. Skipping...
# Processing Record 48 of Set 4 | grenaa
# Processing Record 49 of Set 4 | zhigalovo
# Processing Record 0 of Set 5 | pevek
# Processing Record 1 of Set 5 | eyl
# Processing Record 2 of Set 5 | pathein
# City not found. Skipping...
# Processing Record 3 of Set 5 | los llanos de aridane
# Processing Record 4 of Set 5 | saint anthony
# Processing Record 5 of Set 5 | balingasay
# Processing Record 6 of Set 5 | kunnamangalam
# Processing Record 7 of Set 5 | vadinsk
# Processing Record 8 of Set 5 | hambantota
# Processing Record 9 of Set 5 | severodvinsk
# Processing Record 10 of Set 5 | carnarvon
# Processing Record 11 of Set 5 | mersing
# Processing Record 12 of Set 5 | vestmanna
# Processing Record 13 of Set 5 | tupancireta
# Processing Record 14 of Set 5 | ngunguru
# Processing Record 15 of Set 5 | puntarenas
# Processing Record 16 of Set 5 | axim
# Processing Record 17 of Set 5 | maxixe
# Processing Record 18 of Set 5 | turukhansk
# Processing Record 19 of Set 5 | conceicao do mato dentro
# City not found. Skipping...
# Processing Record 20 of Set 5 | zambezi
# Processing Record 21 of Set 5 | hasaki
# Processing Record 22 of Set 5 | stephenville
# Processing Record 23 of Set 5 | bonavista
# Processing Record 24 of Set 5 | tahta
# City not found. Skipping...
# Processing Record 25 of Set 5 | barahona
# Processing Record 26 of Set 5 | cockburn town
# Processing Record 27 of Set 5 | kaitangata
# Processing Record 28 of Set 5 | manado
# Processing Record 29 of Set 5 | winnemucca
# Processing Record 30 of Set 5 | viedma
# Processing Record 31 of Set 5 | half moon bay
# Processing Record 32 of Set 5 | esperance
# Processing Record 33 of Set 5 | lokosovo
# Processing Record 34 of Set 5 | colesberg
# Processing Record 35 of Set 5 | coihaique
# City not found. Skipping...
# Processing Record 36 of Set 5 | fairbanks
# City not found. Skipping...
# Processing Record 37 of Set 5 | naze
# City not found. Skipping...
# Processing Record 38 of Set 5 | emporia
# Processing Record 39 of Set 5 | rosia
# Processing Record 40 of Set 5 | lagoa
# Processing Record 41 of Set 5 | bosaso
# Processing Record 42 of Set 5 | tezu
# Processing Record 43 of Set 5 | synya
# Processing Record 44 of Set 5 | ushtobe
# Processing Record 45 of Set 5 | bani
# Processing Record 46 of Set 5 | severnoye
# Processing Record 47 of Set 5 | nagato
# Processing Record 48 of Set 5 | pringsewu
# Processing Record 49 of Set 5 | ongandjera
# Processing Record 0 of Set 6 | dalbandin
# Processing Record 1 of Set 6 | calabozo
# Processing Record 2 of Set 6 | san luis
# Processing Record 3 of Set 6 | nzerekore
# Processing Record 4 of Set 6 | touros
# Processing Record 5 of Set 6 | kibaya
# Processing Record 6 of Set 6 | mana
# Processing Record 7 of Set 6 | nieuw amsterdam
# Processing Record 8 of Set 6 | beyneu
# City not found. Skipping...
# Processing Record 9 of Set 6 | mahinog
# Processing Record 10 of Set 6 | nantucket
# Processing Record 11 of Set 6 | namtsy
# Processing Record 12 of Set 6 | biu
# Processing Record 13 of Set 6 | mongu
# Processing Record 14 of Set 6 | nanortalik
# Processing Record 15 of Set 6 | alyangula
# Processing Record 16 of Set 6 | mwinilunga
# Processing Record 17 of Set 6 | sao francisco de paula
# Processing Record 18 of Set 6 | graaff-reinet
# Processing Record 19 of Set 6 | luwuk
# Processing Record 20 of Set 6 | denpasar
# Processing Record 21 of Set 6 | egvekinot
# Processing Record 22 of Set 6 | noumea
# Processing Record 23 of Set 6 | samarai
# Processing Record 24 of Set 6 | yumen
# Processing Record 25 of Set 6 | alamor
# Processing Record 26 of Set 6 | road town
# Processing Record 27 of Set 6 | praia da vitoria
# Processing Record 28 of Set 6 | loandjili
# Processing Record 29 of Set 6 | port macquarie
# City not found. Skipping...
# Processing Record 30 of Set 6 | miles city
# Processing Record 31 of Set 6 | ust-charyshskaya pristan
# Processing Record 32 of Set 6 | gambiran
# Processing Record 33 of Set 6 | lodwar
# Processing Record 34 of Set 6 | nassau
# Processing Record 35 of Set 6 | nyurba
# Processing Record 36 of Set 6 | melo
# Processing Record 37 of Set 6 | vilyuysk
# Processing Record 38 of Set 6 | lakes entrance
# City not found. Skipping...
# Processing Record 39 of Set 6 | najran
# Processing Record 40 of Set 6 | goderich
# Processing Record 41 of Set 6 | baytown
# Processing Record 42 of Set 6 | kasongo-lunda
# Processing Record 43 of Set 6 | pahrump
# City not found. Skipping...
# Processing Record 44 of Set 6 | salekhard
# Processing Record 45 of Set 6 | kununurra
# Processing Record 46 of Set 6 | whitehorse
# Processing Record 47 of Set 6 | caravelas
# Processing Record 48 of Set 6 | zavodoukovsk
# Processing Record 49 of Set 6 | troitsk
# Processing Record 0 of Set 7 | aksarka
# Processing Record 1 of Set 7 | marsa matruh
# Processing Record 2 of Set 7 | kuminskiy
# Processing Record 3 of Set 7 | pisco
# Processing Record 4 of Set 7 | margate
# Processing Record 5 of Set 7 | churapcha
# Processing Record 6 of Set 7 | qaqortoq
# Processing Record 7 of Set 7 | ratnagiri
# Processing Record 8 of Set 7 | chapais
# Processing Record 9 of Set 7 | teeli
# Processing Record 10 of Set 7 | sistranda
# Processing Record 11 of Set 7 | mamallapuram
# Processing Record 12 of Set 7 | tazovskiy
# Processing Record 13 of Set 7 | pangody
# City not found. Skipping...
# Processing Record 14 of Set 7 | sao raimundo das mangabeiras
# Processing Record 15 of Set 7 | barpathar
# Processing Record 16 of Set 7 | gataia
# Processing Record 17 of Set 7 | manta
# Processing Record 18 of Set 7 | malatya
# Processing Record 19 of Set 7 | grindavik
# Processing Record 20 of Set 7 | abu kamal
# Processing Record 21 of Set 7 | constitucion
# Processing Record 22 of Set 7 | soyo
# Processing Record 23 of Set 7 | hameenlinna
# Processing Record 24 of Set 7 | pangnirtung
# Processing Record 25 of Set 7 | sao filipe
# City not found. Skipping...
# Processing Record 26 of Set 7 | baoqing
# Processing Record 27 of Set 7 | makakilo city
# Processing Record 28 of Set 7 | christchurch
# Processing Record 29 of Set 7 | shache
# Processing Record 30 of Set 7 | schalksmuhle
# Processing Record 31 of Set 7 | dubbo
# Processing Record 32 of Set 7 | vao
# Processing Record 33 of Set 7 | kotaparh
# Processing Record 34 of Set 7 | lompoc
# Processing Record 35 of Set 7 | mugur-aksy
# Processing Record 36 of Set 7 | magdagachi
# Processing Record 37 of Set 7 | naryan-mar
# Processing Record 38 of Set 7 | camocim
# Processing Record 39 of Set 7 | todos santos
# Processing Record 40 of Set 7 | luderitz
# Processing Record 41 of Set 7 | mudu
# Processing Record 42 of Set 7 | nchelenge
# Processing Record 43 of Set 7 | barreirinhas
# Processing Record 44 of Set 7 | mendi
# Processing Record 45 of Set 7 | vila velha
# Processing Record 46 of Set 7 | tolosa
# Processing Record 47 of Set 7 | hornepayne
# Processing Record 48 of Set 7 | kutiyana
# Processing Record 49 of Set 7 | george town
# Processing Record 0 of Set 8 | blatna
# Processing Record 1 of Set 8 | le port
# Processing Record 2 of Set 8 | puga
# Processing Record 3 of Set 8 | ossora
# Processing Record 4 of Set 8 | baft
# Processing Record 5 of Set 8 | clovis
# Processing Record 6 of Set 8 | tuatapere
# Processing Record 7 of Set 8 | bathsheba
# City not found. Skipping...
# Processing Record 8 of Set 8 | zhanaozen
# Processing Record 9 of Set 8 | vinh
# Processing Record 10 of Set 8 | marabba
# Processing Record 11 of Set 8 | mount gambier
# Processing Record 12 of Set 8 | altoona
# Processing Record 13 of Set 8 | ixtapa
# Processing Record 14 of Set 8 | nigran
# Processing Record 15 of Set 8 | pedernales
# Processing Record 16 of Set 8 | souillac
# Processing Record 17 of Set 8 | waddan
# Processing Record 18 of Set 8 | torrington
# Processing Record 19 of Set 8 | kushima
# Processing Record 20 of Set 8 | faanui
# Processing Record 21 of Set 8 | srandakan
# Processing Record 22 of Set 8 | kotelnich
# Processing Record 23 of Set 8 | benghazi
# Processing Record 24 of Set 8 | itarema
# Processing Record 25 of Set 8 | sao miguel do araguaia
# Processing Record 26 of Set 8 | bloomfield
# Processing Record 27 of Set 8 | banda aceh
# Processing Record 28 of Set 8 | coari
# Processing Record 29 of Set 8 | usinsk
# Processing Record 30 of Set 8 | saint-joseph
# City not found. Skipping...
# Processing Record 31 of Set 8 | moerai
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 32 of Set 8 | maragogi
# Processing Record 33 of Set 8 | scarborough
# Processing Record 34 of Set 8 | belyy yar
# Processing Record 35 of Set 8 | xiaoshi
# Processing Record 36 of Set 8 | mlowo
# Processing Record 37 of Set 8 | maceio
# Processing Record 38 of Set 8 | garowe
# Processing Record 39 of Set 8 | aksu
# Processing Record 40 of Set 8 | olafsvik
# Processing Record 41 of Set 8 | bangkalan
# Processing Record 42 of Set 8 | tingi
# Processing Record 43 of Set 8 | mulchen
# City not found. Skipping...
# Processing Record 44 of Set 8 | lufkin
# Processing Record 45 of Set 8 | ginir
# Processing Record 46 of Set 8 | mahebourg
# Processing Record 47 of Set 8 | oistins
# Processing Record 48 of Set 8 | skelleftea
# Processing Record 49 of Set 8 | sambava
# Processing Record 0 of Set 9 | dryden
# Processing Record 1 of Set 9 | aldan
# Processing Record 2 of Set 9 | great bend
# Processing Record 3 of Set 9 | pokhara
# Processing Record 4 of Set 9 | palana
# Processing Record 5 of Set 9 | kirakira
# Processing Record 6 of Set 9 | portmore
# Processing Record 7 of Set 9 | itaituba
# Processing Record 8 of Set 9 | beloha
# Processing Record 9 of Set 9 | nelson bay
# Processing Record 10 of Set 9 | mardin
# Processing Record 11 of Set 9 | narang
# Processing Record 12 of Set 9 | matara
# Processing Record 13 of Set 9 | muscatine
# Processing Record 14 of Set 9 | praya
# Processing Record 15 of Set 9 | murwara
# Processing Record 16 of Set 9 | athabasca
# Processing Record 17 of Set 9 | galle
# Processing Record 18 of Set 9 | lisala
# Processing Record 19 of Set 9 | high level
# Processing Record 20 of Set 9 | rocky mountain house
# Processing Record 21 of Set 9 | timizart
# Processing Record 22 of Set 9 | tsumeb
# Processing Record 23 of Set 9 | tiksi
# Processing Record 24 of Set 9 | vostok
# Processing Record 25 of Set 9 | la ronge
# Processing Record 26 of Set 9 | ugoofaaru
# Processing Record 27 of Set 9 | daoukro
# Processing Record 28 of Set 9 | paraiso
# Processing Record 29 of Set 9 | bawku
# Processing Record 30 of Set 9 | micheweni
# Processing Record 31 of Set 9 | xichang
# Processing Record 32 of Set 9 | starokostyantyniv
# Processing Record 33 of Set 9 | yerbogachen
# Processing Record 34 of Set 9 | santa fe
# Processing Record 35 of Set 9 | kamaishi
# Processing Record 36 of Set 9 | stodolishche
# Processing Record 37 of Set 9 | plettenberg bay
# Processing Record 38 of Set 9 | khash
# Processing Record 39 of Set 9 | payson
# Processing Record 40 of Set 9 | grand-santi
# Processing Record 41 of Set 9 | cravo norte
# Processing Record 42 of Set 9 | pemangkat
# Processing Record 43 of Set 9 | eureka
# Processing Record 44 of Set 9 | warrnambool
# Processing Record 45 of Set 9 | miyang
# Processing Record 46 of Set 9 | awbari
# City not found. Skipping...
# Processing Record 47 of Set 9 | malindi
# Processing Record 48 of Set 9 | ilhabela
# Processing Record 49 of Set 9 | vardo
# Processing Record 0 of Set 10 | qeshm
# Processing Record 1 of Set 10 | eydhafushi
# Processing Record 2 of Set 10 | haines junction
# Processing Record 3 of Set 10 | santa rosa
# Processing Record 4 of Set 10 | sur
# Processing Record 5 of Set 10 | waverley
# Processing Record 6 of Set 10 | whitianga
# Processing Record 7 of Set 10 | oussouye
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 8 of Set 10 | grand gaube
# Processing Record 9 of Set 10 | shumskiy
# Processing Record 10 of Set 10 | nebolchi
# Processing Record 11 of Set 10 | xiaoshan
# Processing Record 12 of Set 10 | zhangye
# Processing Record 13 of Set 10 | lasa
# Processing Record 14 of Set 10 | auki
# City not found. Skipping...
# Processing Record 15 of Set 10 | tokur
# Processing Record 16 of Set 10 | makat
# Processing Record 17 of Set 10 | petauke
# Processing Record 18 of Set 10 | opuwo
# City not found. Skipping...
# Processing Record 19 of Set 10 | hirara
# Processing Record 20 of Set 10 | luanda
# City not found. Skipping...
# Processing Record 21 of Set 10 | krasnogorskoye
# Processing Record 22 of Set 10 | balkanabat
# Processing Record 23 of Set 10 | rio gallegos
# Processing Record 24 of Set 10 | trabzon
# Processing Record 25 of Set 10 | bac lieu
# Processing Record 26 of Set 10 | suluq
# Processing Record 27 of Set 10 | isla mujeres
# Processing Record 28 of Set 10 | comodoro rivadavia
# Processing Record 29 of Set 10 | rassvet
# Processing Record 30 of Set 10 | muros
# Processing Record 31 of Set 10 | urucara
# Processing Record 32 of Set 10 | hamilton
# Processing Record 33 of Set 10 | maragheh
# Processing Record 34 of Set 10 | banjar
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 35 of Set 10 | bandipur
# Processing Record 36 of Set 10 | kenai
# Processing Record 37 of Set 10 | rapid valley
# Processing Record 38 of Set 10 | mwense
# Processing Record 39 of Set 10 | vila franca do campo
# Processing Record 40 of Set 10 | mackay
# Processing Record 41 of Set 10 | ola
# Processing Record 42 of Set 10 | trairi
# Processing Record 43 of Set 10 | devonport
# Processing Record 44 of Set 10 | macroom
# Processing Record 45 of Set 10 | lannion
# Processing Record 46 of Set 10 | irati
# Processing Record 47 of Set 10 | north bend
# Processing Record 48 of Set 10 | takoradi
# City not found. Skipping...
# Processing Record 49 of Set 10 | sandwick
# Processing Record 0 of Set 11 | valparaiso
# Processing Record 1 of Set 11 | passo de camaragibe
# Processing Record 2 of Set 11 | yeniseysk
# Processing Record 3 of Set 11 | birjand
# Processing Record 4 of Set 11 | puerto madero
# Processing Record 5 of Set 11 | afikpo
# Processing Record 6 of Set 11 | buchanan
# Processing Record 7 of Set 11 | flin flon
# Processing Record 8 of Set 11 | karratha
# Processing Record 9 of Set 11 | general roca
# Processing Record 10 of Set 11 | varkaus
# Processing Record 11 of Set 11 | police
# --------------------------------
# Data Retrieval Complete
# --------------------------------

# %%
cities_df
# Out:
#              City      Lat      Lng Max Temp Humidity Cloudiness Wind Speed  \
# 0          kokoda  -8.8785  147.741   295.82       86        100       0.97
# 1    saint george  37.1041 -113.584   292.59       47          1       2.57
# 2         kavieng  -2.5744  150.797   298.51       87        100       3.14
# 3       cape town -33.9258  18.4232   292.59       68         20       4.63
# 4            lebu -37.6167   -73.65   288.99       74         11       3.65
# ..            ...      ...      ...      ...      ...        ...        ...
# 610     flin flon  54.7682 -101.865   280.15       42         75       5.66
# 611      karratha -20.7377  116.846   299.99       60          0       4.83
# 612  general roca -39.0333 -67.5833   293.15       40          0        3.6
# 613       varkaus  62.3153   27.873   268.15       54          0       4.63
# 614        police  53.5521  14.5718   274.82       99         99       2.18
#
#     Country        Date
# 0        PG  1616097698
# 1        US  1616097697
# 2        PG  1616097698
# 3        ZA  1616097684
# 4        CL  1616097699
# ..      ...         ...
# 610      CA  1616097857
# 611      AU  1616097954
# 612      AR  1616097954
# 613      FI  1616097955
# 614      PL  1616097955
#
# [615 rows x 9 columns]

# %%
cities_df.dtypes
# Out:
# City          object
# Lat           object
# Lng           object
# Max Temp      object
# Humidity      object
# Cloudiness    object
# Wind Speed    object
# Country       object
# Date          object
# dtype: object

# %%
# Made Duplicate Dataframe So I Could Refer Back To Original DF If Needed
cities_duplicate_df = cities_df
cities_duplicate_df
# Out:
#              City      Lat      Lng Max Temp Humidity Cloudiness Wind Speed  \
# 0          kokoda  -8.8785  147.741   295.82       86        100       0.97
# 1    saint george  37.1041 -113.584   292.59       47          1       2.57
# 2         kavieng  -2.5744  150.797   298.51       87        100       3.14
# 3       cape town -33.9258  18.4232   292.59       68         20       4.63
# 4            lebu -37.6167   -73.65   288.99       74         11       3.65
# ..            ...      ...      ...      ...      ...        ...        ...
# 610     flin flon  54.7682 -101.865   280.15       42         75       5.66
# 611      karratha -20.7377  116.846   299.99       60          0       4.83
# 612  general roca -39.0333 -67.5833   293.15       40          0        3.6
# 613       varkaus  62.3153   27.873   268.15       54          0       4.63
# 614        police  53.5521  14.5718   274.82       99         99       2.18
#
#     Country        Date
# 0        PG  1616097698
# 1        US  1616097697
# 2        PG  1616097698
# 3        ZA  1616097684
# 4        CL  1616097699
# ..      ...         ...
# 610      CA  1616097857
# 611      AU  1616097954
# 612      AR  1616097954
# 613      FI  1616097955
# 614      PL  1616097955
#
# [615 rows x 9 columns]

# %%
# https://datatofish.com/convert-string-to-float-dataframe/
# Converting Columns Into Floats
cities_duplicate_df["Lat"] = pd.to_numeric(cities_duplicate_df["Lat"], errors='coerce')
cities_duplicate_df["Lng"] = pd.to_numeric(cities_duplicate_df["Lng"], errors='coerce')
cities_duplicate_df["Max Temp"] = pd.to_numeric(cities_duplicate_df["Max Temp"], errors='coerce')
cities_duplicate_df["Wind Speed"] = pd.to_numeric(cities_duplicate_df["Wind Speed"], errors='coerce')

# %%
cities_duplicate_df.dtypes
# Out:
# City           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity       object
# Cloudiness     object
# Wind Speed    float64
# Country        object
# Date           object
# dtype: object

# %%
cities_duplicate_df
# Out:
#              City      Lat       Lng  Max Temp Humidity Cloudiness  \
# 0          kokoda  -8.8785  147.7407    295.82       86        100
# 1    saint george  37.1041 -113.5841    292.59       47          1
# 2         kavieng  -2.5744  150.7967    298.51       87        100
# 3       cape town -33.9258   18.4232    292.59       68         20
# 4            lebu -37.6167  -73.6500    288.99       74         11
# ..            ...      ...       ...       ...      ...        ...
# 610     flin flon  54.7682 -101.8650    280.15       42         75
# 611      karratha -20.7377  116.8463    299.99       60          0
# 612  general roca -39.0333  -67.5833    293.15       40          0
# 613       varkaus  62.3153   27.8730    268.15       54          0
# 614        police  53.5521   14.5718    274.82       99         99
#
#      Wind Speed Country        Date
# 0          0.97      PG  1616097698
# 1          2.57      US  1616097697
# 2          3.14      PG  1616097698
# 3          4.63      ZA  1616097684
# 4          3.65      CL  1616097699
# ..          ...     ...         ...
# 610        5.66      CA  1616097857
# 611        4.83      AU  1616097954
# 612        3.60      AR  1616097954
# 613        4.63      FI  1616097955
# 614        2.18      PL  1616097955
#
# [615 rows x 9 columns]

# %%
cities_duplicate_df = cities_duplicate_df.dropna(how="any")
cities_duplicate_df = cities_duplicate_df.fillna("", inplace=False)
cities_duplicate_df
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          kokoda  -8.8785  147.7407    295.82        86         100
# 1    saint george  37.1041 -113.5841    292.59        47           1
# 2         kavieng  -2.5744  150.7967    298.51        87         100
# 3       cape town -33.9258   18.4232    292.59        68          20
# 4            lebu -37.6167  -73.6500    288.99        74          11
# ..            ...      ...       ...       ...       ...         ...
# 610     flin flon  54.7682 -101.8650    280.15        42          75
# 611      karratha -20.7377  116.8463    299.99        60           0
# 612  general roca -39.0333  -67.5833    293.15        40           0
# 613       varkaus  62.3153   27.8730    268.15        54           0
# 614        police  53.5521   14.5718    274.82        99          99
#
#      Wind Speed Country        Date
# 0          0.97      PG  1616097698
# 1          2.57      US  1616097697
# 2          3.14      PG  1616097698
# 3          4.63      ZA  1616097684
# 4          3.65      CL  1616097699
# ..          ...     ...         ...
# 610        5.66      CA  1616097857
# 611        4.83      AU  1616097954
# 612        3.60      AR  1616097954
# 613        4.63      FI  1616097955
# 614        2.18      PL  1616097955
#
# [561 rows x 9 columns]

# %%
# Convert Columns To Int's 
# https://datatofish.com/string-to-integer-dataframe/
cities_duplicate_df["Humidity "] = pd.to_numeric(cities_duplicate_df["Humidity"])
cities_duplicate_df["Cloudiness"] = pd.to_numeric(cities_duplicate_df["Cloudiness"])
cities_duplicate_df["Date"] = pd.to_numeric(cities_duplicate_df["Date"])

# %%
cities_duplicate_df
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          kokoda  -8.8785  147.7407    295.82        86         100
# 1    saint george  37.1041 -113.5841    292.59        47           1
# 2         kavieng  -2.5744  150.7967    298.51        87         100
# 3       cape town -33.9258   18.4232    292.59        68          20
# 4            lebu -37.6167  -73.6500    288.99        74          11
# ..            ...      ...       ...       ...       ...         ...
# 610     flin flon  54.7682 -101.8650    280.15        42          75
# 611      karratha -20.7377  116.8463    299.99        60           0
# 612  general roca -39.0333  -67.5833    293.15        40           0
# 613       varkaus  62.3153   27.8730    268.15        54           0
# 614        police  53.5521   14.5718    274.82        99          99
#
#      Wind Speed Country        Date  Humidity
# 0          0.97      PG  1616097698         86
# 1          2.57      US  1616097697         47
# 2          3.14      PG  1616097698         87
# 3          4.63      ZA  1616097684         68
# 4          3.65      CL  1616097699         74
# ..          ...     ...         ...        ...
# 610        5.66      CA  1616097857         42
# 611        4.83      AU  1616097954         60
# 612        3.60      AR  1616097954         40
# 613        4.63      FI  1616097955         54
# 614        2.18      PL  1616097955         99
#
# [561 rows x 10 columns]

# %%
cities_duplicate_df.dtypes
# Out:
# City           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# Country        object
# Date            int64
# Humidity        int64
# dtype: object

# %%
# Deleting Random Column Made 
# https://www.shanelynn.ie/pandas-drop-delete-dataframe-rows-columns/
cities_duplicate_df = cities_duplicate_df.drop(columns=cities_duplicate_df.columns[9])
cities_duplicate_df
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          kokoda  -8.8785  147.7407    295.82        86         100
# 1    saint george  37.1041 -113.5841    292.59        47           1
# 2         kavieng  -2.5744  150.7967    298.51        87         100
# 3       cape town -33.9258   18.4232    292.59        68          20
# 4            lebu -37.6167  -73.6500    288.99        74          11
# ..            ...      ...       ...       ...       ...         ...
# 610     flin flon  54.7682 -101.8650    280.15        42          75
# 611      karratha -20.7377  116.8463    299.99        60           0
# 612  general roca -39.0333  -67.5833    293.15        40           0
# 613       varkaus  62.3153   27.8730    268.15        54           0
# 614        police  53.5521   14.5718    274.82        99          99
#
#      Wind Speed Country        Date
# 0          0.97      PG  1616097698
# 1          2.57      US  1616097697
# 2          3.14      PG  1616097698
# 3          4.63      ZA  1616097684
# 4          3.65      CL  1616097699
# ..          ...     ...         ...
# 610        5.66      CA  1616097857
# 611        4.83      AU  1616097954
# 612        3.60      AR  1616097954
# 613        4.63      FI  1616097955
# 614        2.18      PL  1616097955
#
# [561 rows x 9 columns]

# %%
#cities_df.replace('', np.nan, inplace=True)

# %%
#cities_df = cities_df.dropna(subset = ["Lat"], inplace=True)

# %%
#cities_df = cities_df.dropna(how="any")

# %%
#cities_df["City"][8]

# %%
#cities_df["Lat"][8]

# %%
# Saving To A CSV file 
cities_duplicate_df.to_csv("weather.csv", encoding="utf-8", index=False)
cities_duplicate_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        kokoda  -8.8785  147.7407    295.82        86         100
# 1  saint george  37.1041 -113.5841    292.59        47           1
# 2       kavieng  -2.5744  150.7967    298.51        87         100
# 3     cape town -33.9258   18.4232    292.59        68          20
# 4          lebu -37.6167  -73.6500    288.99        74          11
#
#    Wind Speed Country        Date
# 0        0.97      PG  1616097698
# 1        2.57      US  1616097697
# 2        3.14      PG  1616097698
# 3        4.63      ZA  1616097684
# 4        3.65      CL  1616097699

# %%
cities_duplicate_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  561.000000  561.000000  561.000000  561.000000  561.000000  561.000000
# mean    18.660489   15.151151  286.435561   71.053476   53.221034    3.479305
# std     33.443013   90.329567   15.257200   21.781070   39.516556    2.341499
# min    -54.800000 -179.166700  232.650000    8.000000    0.000000    0.010000
# 25%     -8.878500  -64.616700  278.390000   58.000000   11.000000    1.590000
# 50%     20.894700   20.952800  291.150000   76.000000   64.000000    3.080000
# 75%     46.485600   90.220100  298.180000   88.000000   91.000000    4.700000
# max     78.218600  179.316700  309.150000  100.000000  100.000000   12.860000
#
#                Date
# count  5.610000e+02
# mean   1.616098e+09
# std    9.789431e+01
# min    1.616097e+09
# 25%    1.616098e+09
# 50%    1.616098e+09
# 75%    1.616098e+09
# max    1.616098e+09

# %%
hundred_humidity_df = cities_duplicate_df.loc[cities_duplicate_df["Humidity"] > 100]
hundred_humidity_df
# Out:
# Empty DataFrame
# Columns: [City, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
lat_x_values = cities_duplicate_df['Lat']
maxtemp_y_values = cities_duplicate_df['Max Temp']
plt.scatter(lat_x_values,maxtemp_y_values,edgecolors="black")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
plt.title('City Latitude vs. Max Temperature Plot (03/18/21)')
plt.grid()
plt.savefig("weatherimages/lat_maxt.png")
plt.show()

# %%
humidity_y_values = cities_duplicate_df['Humidity']
plt.scatter(lat_x_values,humidity_y_values,edgecolors="black")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('City Latitude vs. Humidity (03/18/21)')
plt.grid()
plt.savefig("weatherimages/lat_humidity.png")
plt.show()

# %%
cloudiness_y_values = cities_duplicate_df['Cloudiness']
plt.scatter(lat_x_values,cloudiness_y_values,edgecolors="black")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('City Latitude vs. Cloudiness (03/18/21)')
plt.grid()
plt.savefig("weatherimages/lat_cloudy.png")
plt.show()

# %%
windspeed_y_values = cities_duplicate_df['Wind Speed']
plt.scatter(lat_x_values,windspeed_y_values,edgecolors="black")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('City Latitude vs. Wind Speed (03/18/21)')
plt.grid()
plt.savefig("weatherimages/lat_windspeed.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
northern_hemisphere_df = cities_duplicate_df.loc[cities_duplicate_df["Lat"] >= 0]
northern_hemisphere_df
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 1     saint george  37.1041 -113.5841    292.59        47           1
# 6    san policarpo  12.1791  125.5072    300.41        78          50
# 9        gbadolite   4.2833   21.0167    296.96        76          48
# 10          kiruna  67.8557   20.2251    259.15        78           0
# 12          palmer  42.1584  -72.3287    279.82       100          90
# ..             ...      ...       ...       ...       ...         ...
# 608         afikpo   5.8931    7.9374    300.60        72          61
# 609       buchanan   5.8808  -10.0467    298.15        94          40
# 610      flin flon  54.7682 -101.8650    280.15        42          75
# 613        varkaus  62.3153   27.8730    268.15        54           0
# 614         police  53.5521   14.5718    274.82        99          99
#
#      Wind Speed Country        Date
# 1          2.57      US  1616097697
# 6          2.84      PH  1616097700
# 9          0.79      CD  1616097701
# 10         2.06      SE  1616097701
# 12         4.12      US  1616097702
# ..          ...     ...         ...
# 608        3.15      NG  1616097953
# 609        1.47      LR  1616097953
# 610        5.66      CA  1616097857
# 613        4.63      FI  1616097955
# 614        2.18      PL  1616097955
#
# [380 rows x 9 columns]

# %%
southern_hemisphere_df = cities_duplicate_df.loc[cities_duplicate_df["Lat"] <= 0]
southern_hemisphere_df
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0                 kokoda  -8.8785  147.7407    295.82        86         100
# 2                kavieng  -2.5744  150.7967    298.51        87         100
# 3              cape town -33.9258   18.4232    292.59        68          20
# 4                   lebu -37.6167  -73.6500    288.99        74          11
# 5              busselton -33.6500  115.3333    290.93        84          80
# ..                   ...      ...       ...       ...       ...         ...
# 598                irati -25.4672  -50.6511    301.57        44           0
# 603           valparaiso -33.0393  -71.6273    293.15        52          20
# 604  passo de camaragibe  -9.2368  -35.4901    301.15        65          75
# 611             karratha -20.7377  116.8463    299.99        60           0
# 612         general roca -39.0333  -67.5833    293.15        40           0
#
#      Wind Speed Country        Date
# 0          0.97      PG  1616097698
# 2          3.14      PG  1616097698
# 3          4.63      ZA  1616097684
# 4          3.65      CL  1616097699
# 5          0.89      AU  1616097699
# ..          ...     ...         ...
# 598        1.09      BR  1616097948
# 603        3.09      CL  1616097950
# 604        5.66      BR  1616097951
# 611        4.83      AU  1616097954
# 612        3.60      AR  1616097954
#
# [181 rows x 9 columns]

# %% [markdown]
# #### Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
nh_lat_x_values = northern_hemisphere_df['Lat']
nh_maxtemp_y_values = northern_hemisphere_df['Max Temp']

(slope, intercept, rvalue, pvalue, stderr) = linregress(nh_lat_x_values, nh_maxtemp_y_values)
regress_values = nh_lat_x_values * slope + intercept

# %%
# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# %%
# Create Plot
plt.scatter(nh_lat_x_values,nh_maxtemp_y_values)
plt.plot(nh_lat_x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Max Temp (F)')
plt.title('Northern Hemisphere - Max Temp (F) vs. Latitude Linear Regression')

plt.annotate(line_eq,(20,240),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")
plt.savefig("weatherimages/lat_nhmaxtemp.png")

# Show plot
plt.show()
# Out:
# The r-value is: 0.7928523354331737

# %% [markdown]
# #### Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
sh_lat_x_values = southern_hemisphere_df['Lat']
sh_maxtemp_y_values = southern_hemisphere_df['Max Temp']

(slope, intercept, rvalue, pvalue, stderr) = linregress(sh_lat_x_values, sh_maxtemp_y_values)
regress_values = sh_lat_x_values * slope + intercept

# %%
# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# %%
# Create Plot
plt.scatter(sh_lat_x_values,sh_maxtemp_y_values)
plt.plot(sh_lat_x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Max Temp (F)')
plt.title('Southern Hemisphere - Max Temp (F) vs. Latitude Linear Regression')

plt.annotate(line_eq,(-55,301),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")
plt.savefig("weatherimages/lat_shmaxtemp.png")

# Show plot
plt.show()
# Out:
# The r-value is: 0.43104669508052273

# %% [markdown]
# #### Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
nh_lat_x_values = northern_hemisphere_df['Lat']
nh_humidity_y_values = northern_hemisphere_df['Humidity']

(slope, intercept, rvalue, pvalue, stderr) = linregress(nh_lat_x_values, nh_humidity_y_values)
regress_values = nh_lat_x_values * slope + intercept

# %%
# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# %%
# Create Plot
plt.scatter(nh_lat_x_values,nh_humidity_y_values)
plt.plot(nh_lat_x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression')

plt.annotate(line_eq,(55,301),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")
plt.savefig("weatherimages/lat_nhhumidity.png")

# Show plot
plt.show()
# Out:
# The r-value is: 0.08701721882030095

# %%
#weather_2_df = pd.read_csv('weather2.csv')
#weather_2_df

# %%
#weather_2_df.dtypes

# %%
#weather_2_df = weather_2_df.dropna(how="any")
#weather_2_df = weather_2_df.fillna("", inplace=False)
#weather_2_df

# %%
# count_city = 0 
# for index, row in cities_df.iterrows():
#     random_city = row['City']
#     count_city += 1
#     print(random_city)

# %%
# len(random_city)

# %%
# print(count_city)

# %%
# city_name = 'cancun'
# url = f"http://api.openweathermap.org/data/2.5/weather?q={city_name}&appid={weather_api_key}"
# params = {"key":weather_api_key}
# params['keyword'] = city_name 
# response = requests.get(url,params=params).json()
# response
