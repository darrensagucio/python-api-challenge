# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "Resources/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 615

# %%
lat_lngs

# %%
cities
# Out:
# ['katsuura',
#  'atuona',
#  'makakilo city',
#  'maldonado',
#  'husavik',
#  'chuy',
#  'aykhal',
#  'port lincoln',
#  'iqaluit',
#  'upernavik',
#  'puerto ayora',
#  'tuktoyaktuk',
#  'pevek',
#  'ganzhou',
#  'hermanus',
#  'hobart',
#  'torbay',
#  'yellowknife',
#  'narsaq',
#  'dingle',
#  'ushuaia',
#  'mar del plata',
#  'punta arenas',
#  'longyearbyen',
#  'ahipara',
#  'poplar bluff',
#  'kamenskoye',
#  'east london',
#  'rikitea',
#  'kaitangata',
#  'kerema',
#  'kalamazoo',
#  'arraial do cabo',
#  'malanje',
#  'new norfolk',
#  'barrow',
#  'nizhneyansk',
#  'hambantota',
#  'babanusah',
#  'rawah',
#  'sao felix do xingu',
#  'banjar',
#  'enshi',
#  'jamestown',
#  'butaritari',
#  'vaini',
#  'arman',
#  'grindavik',
#  'hasaki',
#  'bluff',
#  'fernandina beach',
#  'shache',
#  'ponta delgada',
#  'avarua',
#  'cidreira',
#  'taolanaro',
#  'roma',
#  'hami',
#  'hilo',
#  'marv dasht',
#  'evensk',
#  'iskateley',
#  'chernyshevskiy',
#  'fairbanks',
#  'lima',
#  'souillac',
#  'tiksi',
#  'kitimat',
#  'albany',
#  'ginda',
#  'chilapa',
#  'grand river south east',
#  'los llanos de aridane',
#  'kuche',
#  'balykshi',
#  'vieux-habitants',
#  'panormos',
#  'port said',
#  'faanui',
#  'kendari',
#  'lucapa',
#  'cape town',
#  'kavieng',
#  'georgetown',
#  'basco',
#  'huilong',
#  'saint-philippe',
#  'beringovskiy',
#  'kapaa',
#  'qasigiannguit',
#  'margate',
#  'illoqqortoormiut',
#  'hithadhoo',
#  'sentyabrskiy',
#  'bengkulu',
#  'higuey',
#  'thompson',
#  'marzuq',
#  'erdemli',
#  'nelson bay',
#  'lavrentiya',
#  'thinadhoo',
#  'katha',
#  'kruisfontein',
#  'coquimbo',
#  'dikson',
#  'saleaula',
#  'busselton',
#  'qingan',
#  'lewistown',
#  'vandra',
#  'belushya guba',
#  'vallenar',
#  'albufeira',
#  'faya',
#  'akyab',
#  'shimoda',
#  'honjo',
#  'victoria',
#  'provideniya',
#  'pachino',
#  'kadnikov',
#  'richards bay',
#  'port alfred',
#  'aswan',
#  'kieta',
#  'severo-kurilsk',
#  'lithgow',
#  'sabang',
#  'paamiut',
#  'manaus',
#  'buraydah',
#  'qaanaaq',
#  'amderma',
#  'mataura',
#  'monrovia',
#  'bredasdorp',
#  'khatanga',
#  'palabuhanratu',
#  'cururupu',
#  'raudeberg',
#  'izumo',
#  'birao',
#  'namwala',
#  'tazovskiy',
#  'dondo',
#  'karratha',
#  'mahebourg',
#  'bethel',
#  'bambous virieux',
#  'lagoa',
#  'canatlan',
#  'chazuta',
#  'nikolskoye',
#  'matara',
#  'port elizabeth',
#  'elliot',
#  'cherskiy',
#  'vestmannaeyjar',
#  'mehamn',
#  'pisco',
#  'hovd',
#  'tura',
#  'porosozero',
#  'zhezkazgan',
#  'sibolga',
#  'ilulissat',
#  'saskylakh',
#  'kodiak',
#  'goderich',
#  'lompoc',
#  'airai',
#  'vao',
#  'bibiani',
#  'chokurdakh',
#  'macouria',
#  'yialos',
#  'nemuro',
#  'tadine',
#  'norman wells',
#  'george town',
#  'mount gambier',
#  'qui nhon',
#  'high level',
#  'kupang',
#  'yarada',
#  'zolotinka',
#  'vilcun',
#  'catuday',
#  'sawtell',
#  'saint george',
#  'mangai',
#  'castro',
#  'lorengau',
#  'susangerd',
#  'teya',
#  'manokwari',
#  'aksarka',
#  'maarianhamina',
#  'palana',
#  'paita',
#  'lincoln',
#  'trelew',
#  'bizhbulyak',
#  'ribeira grande',
#  'basoko',
#  'aki',
#  'barentsburg',
#  'champerico',
#  'touros',
#  'carnarvon',
#  'jesus maria',
#  'umzimvubu',
#  'mys shmidta',
#  'villarrobledo',
#  'gavle',
#  'amalapuram',
#  'nuuk',
#  'kallidaikurichchi',
#  'bulaevo',
#  'damme',
#  'ilinsko-podomskoye',
#  'berlevag',
#  'ust-kamchatsk',
#  'vardo',
#  'pueblo',
#  'saint-georges',
#  'tabiauea',
#  'opuwo',
#  'ocos',
#  'narathiwat',
#  'verkhoyansk',
#  'tiarei',
#  'attawapiskat',
#  'rungata',
#  'praia',
#  'ruatoria',
#  'sorvag',
#  'chumikan',
#  'darhan',
#  'oranjemund',
#  'khandyga',
#  'port hardy',
#  'san cristobal',
#  'autazes',
#  'kupino',
#  'xinyang',
#  'sitka',
#  'quebrangulo',
#  'clyde river',
#  'nancha',
#  'arkhangelsk',
#  'alta floresta',
#  'poya',
#  'goianinha',
#  'olinda',
#  'corowa',
#  'iranshahr',
#  'amapa',
#  'gwembe',
#  'vicuna',
#  'ilebo',
#  'paldiski',
#  'ponta do sol',
#  'worth',
#  'carutapera',
#  'batagay',
#  'butler',
#  'tasiilaq',
#  'erie',
#  'matay',
#  'duz',
#  'sur',
#  'honningsvag',
#  'bathsheba',
#  'warqla',
#  'the valley',
#  'ahuimanu',
#  'mega',
#  'riviere-du-loup',
#  'normandin',
#  'bubaque',
#  'tsihombe',
#  'saldanha',
#  'pingliang',
#  'padang',
#  'ornskoldsvik',
#  'maragogi',
#  'seoul',
#  'tubruq',
#  'san lawrenz',
#  'kaliganj',
#  'namibe',
#  'jalingo',
#  'yining',
#  'athabasca',
#  'ixtapa',
#  'nynashamn',
#  'naze',
#  'leon',
#  'mocuba',
#  'nchelenge',
#  'samusu',
#  'petropavlovsk-kamchatskiy',
#  'pemba',
#  'bakchar',
#  'lodja',
#  'ambovombe',
#  'fallon',
#  'ostrovnoy',
#  'aklavik',
#  'yorkton',
#  'klaksvik',
#  'kumo',
#  'muriwai beach',
#  'saint anthony',
#  'pangnirtung',
#  'rio gallegos',
#  'salalah',
#  'eunice',
#  'buncrana',
#  'burica',
#  'caohe',
#  'sobolevo',
#  'rafai',
#  'orlovskiy',
#  'smithers',
#  'bom jesus da lapa',
#  'egvekinot',
#  'marsa matruh',
#  'triandria',
#  'moerai',
#  'kungurtug',
#  'amuntai',
#  'namatanai',
#  'port augusta',
#  'constitucion',
#  'bonthe',
#  'sarai',
#  'emba',
#  'luau',
#  'pringsewu',
#  'banda aceh',
#  'thames',
#  'mizque',
#  'tautira',
#  'itacoatiara',
#  'oinacu',
#  'henties bay',
#  'zyryanka',
#  'pitimbu',
#  'cabras',
#  'guerrero negro',
#  'tyukalinsk',
#  'bargal',
#  'caravelas',
#  'celestun',
#  'sterling',
#  'cozumel',
#  'rio grande',
#  'desbiens',
#  'chengde',
#  'camacha',
#  'blajeni',
#  'lhokseumawe',
#  'kahului',
#  'lebu',
#  'nalut',
#  'aguimes',
#  'cabo san lucas',
#  'bayir',
#  'duluth',
#  'tuatapere',
#  'kytlym',
#  'kabale',
#  'vila franca do campo',
#  'diamantino',
#  'kloulklubed',
#  'palmares do sul',
#  'zelenoborskiy',
#  'dosso',
#  'enkhuizen',
#  'velika gorica',
#  'salamiyah',
#  'poso',
#  'esperance',
#  'kunashak',
#  'lerwick',
#  'talaya',
#  'dunedin',
#  'cockburn harbour',
#  'ulladulla',
#  'viline',
#  'bullhead city',
#  'axim',
#  'canutama',
#  'san patricio',
#  'inta',
#  'ocosingo',
#  'katsiveli',
#  'araouane',
#  'zhongshu',
#  'chapais',
#  'torbat-e jam',
#  'luderitz',
#  'novyy urgal',
#  'novikovo',
#  'ada',
#  'terenos',
#  'ugoofaaru',
#  'ialibu',
#  'longlac',
#  'hamilton',
#  'sao filipe',
#  'leningradskiy',
#  'nadvoitsy',
#  'damietta',
#  'khonuu',
#  'vanavara',
#  'churachandpur',
#  'avera',
#  'arlit',
#  'skelleftea',
#  'fort nelson',
#  'pombas',
#  'xucheng',
#  'songjianghe',
#  'hare bay',
#  'syracuse',
#  'zeya',
#  'chakradharpur',
#  'mariel',
#  'torit',
#  'vila velha',
#  'matamoros',
#  'kompaniyivka',
#  'suoyarvi',
#  'santa rosa',
#  'mitsamiouli',
#  'birin',
#  'hammerfest',
#  'burgersdorp',
#  'isangel',
#  'sanming',
#  'intipuca',
#  'ramos arizpe',
#  'oussouye',
#  'jacksonville',
#  'formosa do rio preto',
#  'sola',
#  'codrington',
#  'sompeta',
#  'son tay',
#  'yomitan',
#  'ust-koksa',
#  'utiroa',
#  'denpasar',
#  'geraldton',
#  'okha',
#  'mount isa',
#  'humberto de campos',
#  'hualmay',
#  'illapel',
#  'benghazi',
#  'labuhan',
#  'braganca',
#  'vinh long',
#  'yumen',
#  'milyutinskaya',
#  'grand gaube',
#  'san miguel',
#  'lexington',
#  'hanzhong',
#  'yeppoon',
#  'inhambane',
#  'laguna',
#  'yithion',
#  'derzhavinsk',
#  'kargil',
#  'komsomolskiy',
#  'tolaga bay',
#  'natal',
#  'kabare',
#  'altamont',
#  'luwuk',
#  'camabatela',
#  'mandalgovi',
#  'waipawa',
#  'athens',
#  'parainen',
#  'lahad datu',
#  'khislavichi',
#  'aquiraz',
#  'ustupo',
#  'stokmarknes',
#  'acajutla',
#  'ust-tsilma',
#  'deputatskiy',
#  'gigmoto',
#  'odweyne',
#  'nome',
#  'muzhi',
#  'sheregesh',
#  'cabra',
#  'fukue',
#  'dudinka',
#  'cravo norte',
#  'cap-aux-meules',
#  'havre-saint-pierre',
#  'saint-augustin',
#  'gizo',
#  'koumac',
#  'shelburne',
#  'adrar',
#  'chaoyang',
#  'fevralsk',
#  'rio cuarto',
#  'zhangye',
#  'kosa',
#  'haian',
#  'rawson',
#  'binzhou',
#  'darnah',
#  'balkanabat',
#  'la ronge',
#  'taman',
#  'khomutovka',
#  'killybegs',
#  'altea',
#  'muros',
#  'grand centre',
#  'toliary',
#  'mudanjiang',
#  'khovu-aksy',
#  'port blair',
#  'beaverlodge',
#  'nyurba',
#  'xai-xai',
#  'halalo',
#  'rehoboth',
#  'port keats',
#  'fare',
#  'kirillov',
#  'udachnyy',
#  'tommot',
#  'ozgon',
#  'renqiu',
#  'dumabato',
#  'walvis bay',
#  'amasya',
#  'dukat',
#  'lolua',
#  'srednekolymsk',
#  'yulara',
#  'dinsor',
#  'ambulu',
#  'luxor',
#  'paradwip',
#  'luorong',
#  'rochefort',
#  'comodoro rivadavia',
#  'kaoma',
#  'yanji',
#  'danilov',
#  'felipe carrillo puerto',
#  'zinder',
#  'ravar',
#  'olovyannaya',
#  'te anau',
#  'hirara',
#  'poum',
#  'teknaf',
#  'iwanai',
#  'safford',
#  'gamba',
#  'dolores',
#  'galiwinku',
#  'yanchukan',
#  'razdolinsk',
#  'asau',
#  'inongo',
#  'magadan',
#  'jacmel',
#  'abbeville',
#  'changping',
#  'nanortalik',
#  'mountain home',
#  'gamagori',
#  'brookhaven',
#  'mauswagon',
#  'lazaro cardenas',
#  'north bend',
#  'dubbo',
#  'lac-megantic',
#  'bonito',
#  'mogadishu',
#  'marcona',
#  'zhigansk',
#  'bundaberg',
#  'tual',
#  'georgiyevka',
#  'college',
#  'milkovo',
#  'rabo de peixe',
#  'merauke',
#  'quelimane',
#  'mahibadhoo',
#  'kidal',
#  'biloela',
#  'urumqi',
#  'nanchang',
#  'pomabamba',
#  'salinopolis',
#  'zalantun',
#  'huntsville']

# %%
city = cities[0]
city
# Out:
# 'katsuura'

# %%
url = f"http://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}"

# %%
weather_response = requests.get(url)
city_weather_json = weather_response.json()
city_weather_json
# Out:
# {'coord': {'lon': 140.3, 'lat': 35.1333},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 285.72,
#   'feels_like': 284.57,
#   'temp_min': 285.37,
#   'temp_max': 286.15,
#   'pressure': 1017,
#   'humidity': 82},
#  'visibility': 10000,
#  'wind': {'speed': 1.54, 'deg': 110},
#  'clouds': {'all': 75},
#  'dt': 1616074467,
#  'sys': {'type': 1,
#   'id': 8074,
#   'country': 'JP',
#   'sunrise': 1616013947,
#   'sunset': 1616057289},
#  'timezone': 32400,
#  'id': 2112309,
#  'name': 'Katsuura',
#  'cod': 200}

# %%
max_temp = city_weather_json['main']['temp_max']
max_temp
# Out:
# 286.15

# %%
city_weather_json['coord']
# Out:
# {'lon': 140.3, 'lat': 35.1333}

# %%
city_weather_json['clouds']['all']
# Out:
# 75

# %%
forecast = city_weather_json["weather"][0]["main"]
forecast
# Out:
# 'Clouds'

# %%
latcheck = city_weather_json["coord"]["lat"]
latcheck
# Out:
# 35.1333

# %%
cities_df = pd.DataFrame({"City":cities,})
cities_df
# Out:
#               City
# 0         katsuura
# 1           atuona
# 2    makakilo city
# 3        maldonado
# 4          husavik
# ..             ...
# 610       nanchang
# 611      pomabamba
# 612    salinopolis
# 613       zalantun
# 614     huntsville
#
# [615 rows x 1 columns]

# %%
cities_df['Lat']= ""
cities_df['Lng']= ""
cities_df['Max Temp']= ""
cities_df['Humidity']= ""
cities_df['Cloudiness']= ""
cities_df['Wind Speed']= ""
cities_df['Country']= ""
cities_df['Date']= ""
cities_df
# Out:
#               City Lat Lng Max Temp Humidity Cloudiness Wind Speed Country  \
# 0         katsuura
# 1           atuona
# 2    makakilo city
# 3        maldonado
# 4          husavik
# ..             ...  ..  ..      ...      ...        ...        ...     ...
# 610       nanchang
# 611      pomabamba
# 612    salinopolis
# 613       zalantun
# 614     huntsville
#
#     Date
# 0
# 1
# 2
# 3
# 4
# ..   ...
# 610
# 611
# 612
# 613
# 614
#
# [615 rows x 9 columns]

# %%
base_url = "http://api.openweathermap.org/data/2.5/weather"
city_name = cities[0] # where cities[0] is katsuura
params = {"q":city_name,
          "appid":weather_api_key}
get_city_response = requests.get(base_url, params=params).json()
get_city_response
# Out:
# {'coord': {'lon': 140.3, 'lat': 35.1333},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 285.98,
#   'feels_like': 284.83,
#   'temp_min': 285.93,
#   'temp_max': 286.15,
#   'pressure': 1018,
#   'humidity': 88},
#  'visibility': 10000,
#  'wind': {'speed': 2.06, 'deg': 60},
#  'clouds': {'all': 75},
#  'dt': 1616077077,
#  'sys': {'type': 1,
#   'id': 8074,
#   'country': 'JP',
#   'sunrise': 1616013947,
#   'sunset': 1616057289},
#  'timezone': 32400,
#  'id': 2112309,
#  'name': 'Katsuura',
#  'cod': 200}

# %%
base_url = "http://api.openweathermap.org/data/2.5/weather"
city_name = cities[1] 
params = {"q":city_name,
          "appid":weather_api_key}
get_city_response = requests.get(base_url, params=params).json()
get_city_response
# Out:
# {'coord': {'lon': -139.0333, 'lat': -9.8},
#  'weather': [{'id': 500,
#    'main': 'Rain',
#    'description': 'light rain',
#    'icon': '10n'}],
#  'base': 'stations',
#  'main': {'temp': 299.78,
#   'feels_like': 300.85,
#   'temp_min': 299.78,
#   'temp_max': 299.78,
#   'pressure': 1011,
#   'humidity': 78,
#   'sea_level': 1011,
#   'grnd_level': 1003},
#  'visibility': 10000,
#  'wind': {'speed': 5.54, 'deg': 67, 'gust': 6.17},
#  'rain': {'1h': 0.2},
#  'clouds': {'all': 69},
#  'dt': 1616078887,
#  'sys': {'country': 'PF', 'sunrise': 1616080812, 'sunset': 1616124476},
#  'timezone': -34200,
#  'id': 4020109,
#  'name': 'Atuona',
#  'cod': 200}

# %%
base_url = "http://api.openweathermap.org/data/2.5/weather?"
params = {"appid":weather_api_key}

set_number = 0
record_number = 0 

print("Beginning Data Retrieval")
print("--------------------------------")

# For Loop To Extract Data From API 
for index, row in cities_df.iterrows():
    
    #
    choosing_city = row['City']
    
    #  
    params['q'] = choosing_city
    
    #
    get_city_response = requests.get(base_url, params=params).json()
    
    try:
        cities_df.loc[index, 'Lat'] = get_city_response["coord"]["lat"]
        cities_df.loc[index, 'Lng'] = get_city_response["coord"]["lon"]
        cities_df.loc[index, 'Max Temp'] = get_city_response["main"]["temp_max"]
        cities_df.loc[index, 'Humidity'] = get_city_response["main"]["humidity"]
        cities_df.loc[index, 'Cloudiness'] = get_city_response["clouds"]["all"]
        cities_df.loc[index, 'Wind Speed'] = get_city_response["wind"]["speed"]
        cities_df.loc[index, 'Country'] = get_city_response["sys"]["country"]
        cities_df.loc[index, 'Date'] = get_city_response["dt"]
        record_number += 1 
        if record_number == 50:
            record_number = 0 
            set_number += 1
        print(f"Processing Record {record_number} of Set {set_number} | {choosing_city}") 
    
    except (KeyError):
        print("City not found. Skipping...")

print("--------------------------------")
print("Data Retrieval Complete")
print("--------------------------------")
# Out:
# Beginning Data Retrieval
# --------------------------------
# Processing Record 1 of Set 0 | katsuura
# Processing Record 2 of Set 0 | atuona
# Processing Record 3 of Set 0 | makakilo city
# Processing Record 4 of Set 0 | maldonado
# Processing Record 5 of Set 0 | husavik
# Processing Record 6 of Set 0 | chuy
# Processing Record 7 of Set 0 | aykhal
# Processing Record 8 of Set 0 | port lincoln
# Processing Record 9 of Set 0 | iqaluit
# Processing Record 10 of Set 0 | upernavik
# Processing Record 11 of Set 0 | puerto ayora
# Processing Record 12 of Set 0 | tuktoyaktuk
# Processing Record 13 of Set 0 | pevek
# Processing Record 14 of Set 0 | ganzhou
# Processing Record 15 of Set 0 | hermanus
# Processing Record 16 of Set 0 | hobart
# Processing Record 17 of Set 0 | torbay
# Processing Record 18 of Set 0 | yellowknife
# Processing Record 19 of Set 0 | narsaq
# Processing Record 20 of Set 0 | dingle
# Processing Record 21 of Set 0 | ushuaia
# Processing Record 22 of Set 0 | mar del plata
# Processing Record 23 of Set 0 | punta arenas
# Processing Record 24 of Set 0 | longyearbyen
# Processing Record 25 of Set 0 | ahipara
# Processing Record 26 of Set 0 | poplar bluff
# City not found. Skipping...
# Processing Record 27 of Set 0 | east london
# Processing Record 28 of Set 0 | rikitea
# Processing Record 29 of Set 0 | kaitangata
# Processing Record 30 of Set 0 | kerema
# Processing Record 31 of Set 0 | kalamazoo
# Processing Record 32 of Set 0 | arraial do cabo
# Processing Record 33 of Set 0 | malanje
# Processing Record 34 of Set 0 | new norfolk
# Processing Record 35 of Set 0 | barrow
# City not found. Skipping...
# Processing Record 36 of Set 0 | hambantota
# City not found. Skipping...
# Processing Record 37 of Set 0 | rawah
# Processing Record 38 of Set 0 | sao felix do xingu
# Processing Record 39 of Set 0 | banjar
# Processing Record 40 of Set 0 | enshi
# Processing Record 41 of Set 0 | jamestown
# Processing Record 42 of Set 0 | butaritari
# Processing Record 43 of Set 0 | vaini
# Processing Record 44 of Set 0 | arman
# Processing Record 45 of Set 0 | grindavik
# Processing Record 46 of Set 0 | hasaki
# Processing Record 47 of Set 0 | bluff
# Processing Record 48 of Set 0 | fernandina beach
# Processing Record 49 of Set 0 | shache
# Processing Record 0 of Set 1 | ponta delgada
# Processing Record 1 of Set 1 | avarua
# Processing Record 2 of Set 1 | cidreira
# City not found. Skipping...
# Processing Record 3 of Set 1 | roma
# Processing Record 4 of Set 1 | hami
# Processing Record 5 of Set 1 | hilo
# City not found. Skipping...
# Processing Record 6 of Set 1 | evensk
# Processing Record 7 of Set 1 | iskateley
# Processing Record 8 of Set 1 | chernyshevskiy
# Processing Record 9 of Set 1 | fairbanks
# Processing Record 10 of Set 1 | lima
# Processing Record 11 of Set 1 | souillac
# Processing Record 12 of Set 1 | tiksi
# Processing Record 13 of Set 1 | kitimat
# Processing Record 14 of Set 1 | albany
# Processing Record 15 of Set 1 
# Processing Record 40 of Set 4 | butler
# Processing Record 41 of Set 4 | tasiilaq
# Processing Record 42 of Set 4 | erie
# Processing Record 43 of Set 4 | matay
# City not found. Skipping...
# Processing Record 44 of Set 4 | sur
# Processing Record 45 of Set 4 | honningsvag
# Processing Record 46 of Set 4 | bathsheba
# City not found. Skipping...
# Processing Record 47 of Set 4 | the valley
# Processing Record 48 of Set 4 | ahuimanu
# Processing Record 49 of Set 4 | mega
# Processing Record 0 of Set 5 | riviere-du-loup
# Processing Record 1 of Set 5 | normandin
# Processing Record 2 of Set 5 | bubaque
# City not found. Skipping...
# Processing Record 3 of Set 5 | saldanha
# Processing Record 4 of Set 5 | pingliang
# Processing Record 5 of Set 5 | padang
# Processing Record 6 of Set 5 | ornskoldsvik
# Processing Record 7 of Set 5 | maragogi
# Processing Record 8 of Set 5 | seoul
# City not found. Skipping...
# Processing Record 9 of Set 5 | san lawrenz
# Processing Record 10 of Set 5 | kaliganj
# Processing Record 11 of Set 5 | namibe
# Processing Record 12 of Set 5 | jalingo
# Processing Record 13 of Set 5 | yining
# Processing Record 14 of Set 5 | athabasca
# Processing Record 15 of Set 5 | ixtapa
# Processing Record 16 of Set 5 | nynashamn
# Processing Record 17 of Set 5 | naze
# Processing Record 18 of Set 5 | leon
# Processing Record 19 of Set 5 | mocuba
# Processing Record 20 of Set 5 | nchelenge
# City not found. Skipping...
# Processing Record 21 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 22 of Set 5 | pemba
# Processing Record 23 of Set 5 | bakchar
# Processing Record 24 of Set 5 | lodja
# Processing Record 25 of Set 5 | ambovombe
# Processing Record 26 of Set 5 | fallon
# Processing Record 27 of Set 5 | ostrovnoy
# Processing Record 28 of Set 5 | aklavik
# Processing Record 29 of Set 5 | yorkton
# Processing Record 30 of Set 5 | klaksvik
# Processing Record 31 of Set 5 | kumo
# Processing Record 32 of Set 5 | muriwai beach
# Processing Record 33 of Set 5 | saint anthony
# Processing Record 34 of Set 5 | pangnirtung
# Processing Record 35 of Set 5 | rio gallegos
# Processing Record 36 of Set 5 | salalah
# Processing Record 37 of Set 5 | eunice
# Processing Record 38 of Set 5 | buncrana
# City not found. Skipping...
# Processing Record 39 of Set 5 | caohe
# Processing Record 40 of Set 5 | sobolevo
# Processing Record 41 of Set 5 | rafai
# Processing Record 42 of Set 5 | orlovskiy
# Processing Record 43 of Set 5 | smithers
# Processing Record 44 of Set 5 | bom jesus da lapa
# Processing Record 45 of Set 5 | egvekinot
# Processing Record 46 of Set 5 | marsa matruh
# Processing Record 47 of Set 5 | triandria
# Processing Record 48 of Set 5 | moerai
# Processing Record 49 of Set 5 | kungurtug
# Processing Record 0 of Set 6 | amuntai
# Processing Record 1 of Set 6 | namatanai
# Processing Record 2 of Set 6 | port augusta
# Processing Record 3 of Set 6 | constitucion
# Processing Record 4 of Set 6 | bonthe
# Processing Record 5 of Set 6 | sarai
# Processing Record 6 of Set 6 | emba
# Processing Record 7 of Set 6 | luau
# Processing Record 8 of Set 6 | pringsewu
# Processing Record 9 of Set 6 | banda aceh
# Processing Record 10 of Set 6 | thames
# Processing Record 11 of Set 6 | mizque
# Processing Record 12 of Set 6 | tautira
# Processing Record 13 of Set 6 | itacoatiara
# Processing Record 14 of Set 6 | oinacu
# Processing Record 15 of Set 6 | henties bay
# Processing Record 16 of Set 6 | zyryanka
# Processing Record 17 of Set 6 | pitimbu
# Processing Record 18 of Set 6 | cabras
# Processing Record 19 of Set 6 | guerrero negro
# Processing Record 20 of Set 6 | tyukalinsk
# City not found. Skipping...
# Processing Record 21 of Set 6 | caravelas
# Processing Record 22 of Set 6 | celestun
# Processing Record 23 of Set 6 | sterling
# Processing Record 24 of Set 6 | cozumel
# Processing Record 25 of Set 6 | rio grande
# Processing Record 26 of Set 6 | desbiens
# Processing Record 27 of Set 6 | chengde
# Processing Record 28 of Set 6 | camacha
# Processing Record 29 of Set 6 | blajeni
# Processing Record 30 of Set 6 | lhokseumawe
# Processing Record 31 of Set 6 | kahului
# Processing Record 32 of Set 6 | lebu
# Processing Record 33 of Set 6 | nalut
# Processing Record 34 of Set 6 | aguimes
# Processing Record 35 of Set 6 | cabo san lucas
# Processing Record 36 of Set 6 | bayir
# Processing Record 37 of Set 6 | duluth
# Processing Record 38 of Set 6 | tuatapere
# City not found. Skipping...
# Processing Record 39 of Set 6 | kabale
# Processing Record 40 of Set 6 | vila franca do campo
# Processing Record 41 of Set 6 | diamantino
# Processing Record 42 of Set 6 | kloulklubed
# Processing Record 43 of Set 6 | palmares do sul
# Processing Record 44 of Set 6 | zelenoborskiy
# Processing Record 45 of Set 6 | dosso
# Processing Record 46 of Set 6 | enkhuizen
# Processing Record 47 of Set 6 | velika gorica
# Processing Record 48 of Set 6 | salamiyah
# Processing Record 49 of Set 6 | poso
# Processing Record 0 of Set 7 | esperance
# Processing Record 1 of Set 7 | kunashak
# Processing Record 2 of Set 7 | lerwick
# Processing Record 3 of Set 7 | talaya
# Processing Record 4 of Set 7 | dunedin
# City not found. Skipping...
# Processing Record 5 of Set 7 | ulladulla
# Processing Record 6 of Set 7 | viline
# Processing Record 7 of Set 7 | bullhead city
# Processing Record 8 of Set 7 | axim
# Processing Record 9 of Set 7 | canutama
# Processing Record 10 of Set 7 | san patricio
# Processing Record 11 of Set 7 | inta
# Processing Record 12 of Set 7 | ocosingo
# City not found. Skipping...
# Processing Record 13 of Set 7 | araouane
# Processing Record 14 of Set 7 | zhongshu
# Processing Record 15 of Set 7 | chapais
# Processing Record 16 of Set 7 | torbat-e jam
# Processing Record 17 of Set 7 | luderitz
# Processing Record 18 of Set 7 | novyy urgal
# Processing Record 19 of Set 7 | novikovo
# Processing Record 20 of Set 7 | ada
# Processing Record 21 of Set 7 | terenos
# Processing Record 22 of Set 7 | ugoofaaru
# Processing Record 23 of Set 7 | ialibu
# City not found. Skipping...
# Processing Record 24 of Set 7 | hamilton
# Processing Record 25 of Set 7 | sao filipe
# Processing Record 26 of Set 7 | leningradskiy
# Processing Record 27 of Set 7 | nadvoitsy
# Processing Record 28 of Set 7 | damietta
# City not found. Skipping...
# Processing Record 29 of Set 7 | vanavara
# Processing Record 30 of Set 7 | churachandpur
# Processing Record 3 of Set 9 | acajutla
# Processing Record 4 of Set 9 | ust-tsilma
# Processing Record 5 of Set 9 | deputatskiy
# Processing Record 6 of Set 9 | gigmoto
# Processing Record 7 of Set 9 | odweyne
# Processing Record 8 of Set 9 | nome
# Processing Record 9 of Set 9 | muzhi
# Processing Record 10 of Set 9 | sheregesh
# Processing Record 11 of Set 9 | cabra
# Processing Record 12 of Set 9 | fukue
# Processing Record 13 of Set 9 | dudinka
# Processing Record 14 of Set 9 | cravo norte
# Processing Record 15 of Set 9 | cap-aux-meules
# Processing Record 16 of Set 9 | havre-saint-pierre
# Processing Record 17 of Set 9 | saint-augustin
# Processing Record 18 of Set 9 | gizo
# Processing Record 19 of Set 9 | koumac
# Processing Record 20 of Set 9 | shelburne
# Processing Record 21 of Set 9 | adrar
# Processing Record 22 of Set 9 | chaoyang
# City not found. Skipping...
# Processing Record 23 of Set 9 | rio cuarto
# Processing Record 24 of Set 9 | zhangye
# Processing Record 25 of Set 9 | kosa
# Processing Record 26 of Set 9 | haian
# Processing Record 27 of Set 9 | rawson
# Processing Record 28 of Set 9 | binzhou
# Processing Record 29 of Set 9 | darnah
# Processing Record 30 of Set 9 | balkanabat
# Processing Record 31 of Set 9 | la ronge
# Processing Record 32 of Set 9 | taman
# Processing Record 33 of Set 9 | khomutovka
# Processing Record 34 of Set 9 | killybegs
# Processing Record 35 of Set 9 | altea
# Processing Record 36 of Set 9 | muros
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 37 of Set 9 | mudanjiang
# Processing Record 38 of Set 9 | khovu-aksy
# Processing Record 39 of Set 9 | port blair
# Processing Record 40 of Set 9 | beaverlodge
# Processing Record 41 of Set 9 | nyurba
# Processing Record 42 of Set 9 | xai-xai
# City not found. Skipping...
# Processing Record 43 of Set 9 | rehoboth
# Processing Record 44 of Set 9 | port keats
# Processing Record 45 of Set 9 | fare
# Processing Record 46 of Set 9 | kirillov
# Processing Record 47 of Set 9 | udachnyy
# Processing Record 48 of Set 9 | tommot
# City not found. Skipping...
# Processing Record 49 of Set 9 | renqiu
# Processing Record 0 of Set 10 | dumabato
# Processing Record 1 of Set 10 | walvis bay
# Processing Record 2 of Set 10 | amasya
# Processing Record 3 of Set 10 | dukat
# City not found. Skipping...
# Processing Record 4 of Set 10 | srednekolymsk
# Processing Record 5 of Set 10 | yulara
# City not found. Skipping...
# Processing Record 6 of Set 10 | ambulu
# Processing Record 7 of Set 10 | luxor
# City not found. Skipping...
# Processing Record 8 of Set 10 | luorong
# Processing Record 9 of Set 10 | rochefort
# Processing Record 10 of Set 10 | comodoro rivadavia
# Processing Record 11 of Set 10 | kaoma
# Processing Record 12 of Set 10 | yanji
# Processing Record 13 of Set 10 | danilov
# Processing Record 14 of Set 10 | felipe carrillo puerto
# Processing Record 15 of Set 10 | zinder
# Processing Record 16 of Set 10 | ravar
# Processing Record 17 of Set 10 | olovyannaya
# Processing Record 18 of Set 10 | te anau
# Processing Record 19 of Set 10 | hirara
# Processing Record 20 of Set 10 | poum
# Processing Record 21 of Set 10 | teknaf
# Processing Record 22 of Set 10 | iwanai
# Processing Record 23 of Set 10 | safford
# Processing Record 24 of Set 10 | gamba
# Processing Record 25 of Set 10 | dolores
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 26 of Set 10 | razdolinsk
# Processing Record 27 of Set 10 | asau
# Processing Record 28 of Set 10 | inongo
# Processing Record 29 of Set 10 | magadan
# Processing Record 30 of Set 10 | jacmel
# Processing Record 31 of Set 10 | abbeville
# Processing Record 32 of Set 10 | changping
# Processing Record 33 of Set 10 | nanortalik
# Processing Record 34 of Set 10 | mountain home
# Processing Record 35 of Set 10 | gamagori
# Processing Record 36 of Set 10 | brookhaven
# City not found. Skipping...
# Processing Record 37 of Set 10 | lazaro cardenas
# Processing Record 38 of Set 10 | north bend
# Processing Record 39 of Set 10 | dubbo
# Processing Record 40 of Set 10 | lac-megantic
# Processing Record 41 of Set 10 | bonito
# Processing Record 42 of Set 10 | mogadishu
# City not found. Skipping...
# Processing Record 43 of Set 10 | zhigansk
# Processing Record 44 of Set 10 | bundaberg
# Processing Record 45 of Set 10 | tual
# Processing Record 46 of Set 10 | georgiyevka
# Processing Record 47 of Set 10 | college
# Processing Record 48 of Set 10 | milkovo
# Processing Record 49 of Set 10 | rabo de peixe
# Processing Record 0 of Set 11 | merauke
# Processing Record 1 of Set 11 | quelimane
# Processing Record 2 of Set 11 | mahibadhoo
# Processing Record 3 of Set 11 | kidal
# Processing Record 4 of Set 11 | biloela
# Processing Record 5 of Set 11 | urumqi
# Processing Record 6 of Set 11 | nanchang
# Processing Record 7 of Set 11 | pomabamba
# Processing Record 8 of Set 11 | salinopolis
# Processing Record 9 of Set 11 | zalantun
# Processing Record 10 of Set 11 | huntsville
# --------------------------------
# Data Retrieval Complete
# --------------------------------

# %%
cities_df
# Out:
#               City      Lat      Lng Max Temp Humidity Cloudiness Wind Speed  \
# 0         katsuura  35.1333    140.3   285.93       85        100       5.33
# 1           atuona     -9.8 -139.033   299.78       78         69       5.54
# 2    makakilo city  21.3469 -158.086   295.15       73          1       2.57
# 3        maldonado -34.6667 -54.9167   292.15       55         75       5.66
# 4          husavik  66.0449 -17.3389   285.15       62         75       7.72
# ..             ...      ...      ...      ...      ...        ...        ...
# 610       nanchang  28.6833  115.883   287.48       90         75        4.1
# 611      pomabamba  -8.8333 -77.4667   287.07       66         92       1.33
# 612    salinopolis  -0.6136 -47.3561   299.89       85        100       4.53
# 613       zalantun       48  122.717   270.76       58        100       1.82
# 614     huntsville  34.7304 -86.5861   288.15       67          1       8.23
#
#     Country        Date
# 0        JP  1616079299
# 1        PF  1616079299
# 2        US  1616079300
# 3        UY  1616079566
# 4        IS  1616079668
# ..      ...         ...
# 610      CN  1616079548
# 611      PE  1616079548
# 612      BR  1616079548
# 613      CN  1616079549
# 614      US  1616079475
#
# [615 rows x 9 columns]

# %%
# count_city = 0 
# for index, row in cities_df.iterrows():
#     random_city = row['City']
#     count_city += 1
#     print(random_city)

# %%
# len(random_city)

# %%
# print(count_city)

# %%
# city_name = 'cancun'
# url = f"http://api.openweathermap.org/data/2.5/weather?q={city_name}&appid={weather_api_key}"
# params = {"key":weather_api_key}
# params['keyword'] = city_name 
# response = requests.get(url,params=params).json()
# response
